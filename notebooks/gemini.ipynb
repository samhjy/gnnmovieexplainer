# %%
import google.generativeai as genai
import os
import json

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import precision_score, recall_score
import re
# Out:
# /var/folders/rh/6zv88sms5vddqjk7_7d0f5v00000gn/T/ipykernel_35841/4214248854.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
# Load the datasets
movies_df = pd.read_csv(MOVIES_FILE_PATH)
ratings_df = pd.read_csv(RATINGS_FILE_PATH)

merged_df = pd.merge(ratings_df, movies_df, on='movieId', how='inner')
merged_df.head()
# Out:
#    userId  movieId  rating  timestamp                        title  \
# 0       1        1     4.0  964982703             Toy Story (1995)
# 1       1        3     4.0  964981247      Grumpier Old Men (1995)
# 2       1        6     4.0  964982224                  Heat (1995)
# 3       1       47     5.0  964983815  Seven (a.k.a. Se7en) (1995)
# 4       1       50     5.0  964982931   Usual Suspects, The (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                               Comedy|Romance
# 2                        Action|Crime|Thriller
# 3                             Mystery|Thriller
# 4                       Crime|Mystery|Thriller

# %%
train_df, test_df = train_test_split(merged_df, test_size=0.2, random_state=42)

# %%
# Get unique test users
test_users = test_df['userId'].unique()
len(test_users)
# Out:
# 610

# %%
# Creating a dictionary of user histories
user_histories = {}

# Iterate over each row in the merged DataFrame
for _, row in train_df.iterrows():
    user_id = row['userId']
    movie_info = {
        'movieId': row['movieId'],
        'title': row['title'],
        'rating': row['rating'],
        'genres': row['genres']
    }
    
    # Initialize list if user_id is not yet in dictionary
    if user_id not in user_histories:
        user_histories[user_id] = []
    
    # Append the movie info to the user's history
    user_histories[user_id].append(movie_info)

# Display the user histories
len(user_histories)
# Out:
# 610

# %%
genai.configure(api_key=GEMINI_API_KEY)

def get_gemini_recommendations(prompt):
    model = genai.GenerativeModel("gemini-1.5-flash")
    response = model.generate_content(prompt)
    # print(response.text)
    return (response.text)

# %%
for user in test_users:
    ratings = user_histories.get(user)
    prompt = f"Based on the user's previous movie ratings: {ratings}, recommend 50 new movies from the popular MovieLens Latest dataset from https://files.grouplens.org/datasets/movielens/ml-latest-small.zip for the user to watch." 
    prompt += """Respond with only the titles in json format: OUTPUT = {
"recommendation": [/* array of movies */]
}"""
    recommendation = get_gemini_recommendations(prompt)
       
    titles_list = recommendation.split("{")[1]
    recommendations_list = eval(re.search(r'\[.*?\]', titles_list, re.DOTALL).group(0))
    recommendations_without_years = [re.sub(r"\s\(\d{4}\)$", "", title) for title in recommendations_list]
    all_recommendations[user] = recommendations_without_years

# %%
def get_high_rated_movies_by_user(movies_df, ratings_df):
    # Merge movies and ratings data to include movie titles
    merged_df = pd.merge(ratings_df, movies_df, on='movieId', how='inner')
    
    # Filter for ratings >= 4
    high_rated_df = merged_df[merged_df['rating'] >= 4]
    
    # Group by userId and collect titles in a list for each user
    user_high_rated_movies = high_rated_df.groupby('userId')['title'].apply(list).to_dict()
    
    return user_high_rated_movies

# Usage
user_high_rated_movies = get_high_rated_movies_by_user(movies_df, ratings_df)

# %%
# Initialize counters for cumulative precision@k and recall@k
total_precision_at_k = 0
total_recall_at_k = 0
user_count = len(test_users)

# Set the value of k
k = 50  # You can adjust this to any desired value of k

# Iterate through each user to calculate precision@k and recall@k
for user in test_users:
    test = user_high_rated_movies.get(user, [])
    titles = all_recommendations.get(user, [])[:k]  # Take only the top k recommendations

    # Find relevant recommendations based on fuzzy matching (limited to top k recommendations)
    relevant_recommended = set()
    for recommended_movie in titles:
        for liked_movie in test:
            if recommended_movie in liked_movie or liked_movie in recommended_movie:
                relevant_recommended.add(recommended_movie)
                break  # Break to avoid duplicate addition

    # Calculate precision@k and recall@k for the current user
    precision_at_k = len(relevant_recommended) / k if titles else 0
    recall_at_k = len(relevant_recommended) / len(test) if test else 0

    # Accumulate precision@k and recall@k
    total_precision_at_k += precision_at_k
    total_recall_at_k += recall_at_k

    print(f"User: {user}")
    print("Relevant Recommendations (top k):", relevant_recommended)
    print("Precision@k:", precision_at_k)
    print("Recall@k:", recall_at_k)
    print("-" * 40)

# Calculate average precision@k and recall@k across all users
average_precision_at_k = total_precision_at_k / user_count if user_count else 0
average_recall_at_k = total_recall_at_k / user_count if user_count else 0

print(f"Average Precision@{k} across all users:", average_precision_at_k)
print(f"Average Recall@{k} across all users:", average_recall_at_k)
# Out:
# User: 432
# Relevant Recommendations (top k): {'Forrest Gump', 'Inception', 'Gladiator', "Schindler's List", 'City of God (Cidade de Deus)'}
# Precision@k: 0.1
# Recall@k: 0.03496503496503497
# ----------------------------------------
# User: 288
# Relevant Recommendations (top k): {'WALL·E', 'Forrest Gump', 'Pulp Fiction', 'Memento', 'Braveheart', 'Up', 'Goodfellas', 'Spirited Away (Sen to Chihiro no kamikakushi)', "Schindler's List", 'American History X', 'Rear Window'}
# Precision@k: 0.22
# Recall@k: 0.03985507246376811
# ----------------------------------------
# User: 599
# Relevant Recommendations (top k): {'Pulp Fiction', 'Memento', 'Goodfellas', 'Fight Club', 'Terminator 2: Judgment Day', 'Good Will Hunting', 'Se7en', 'American History X'}
# Precision@k: 0.16
# Recall@k: 0.042105263157894736
# ----------------------------------------
# User: 42
# Relevant Recommendations (top k): {'Forrest Gump', 'Pulp Fiction', 'Goodfellas', 'Saving Private Ryan', "Schindler's List"}
# Precision@k: 0.1
# Recall@k: 0.019305019305019305
# ----------------------------------------
# User: 75
# Relevant Recommendations (top k): set()
# Precision@k: 0.0
# Recall@k: 0.0
# ----------------------------------------
# User: 51
# Relevant Recommendations (top k): {'Requiem for a Dream', 'Terminator 2: Judgment Day'}
# Precision@k: 0.04
# Recall@k: 0.00966183574879227
# ----------------------------------------
# User: 354
# Relevant Recommendations (top k): {'Forrest Gump', 'Pulp Fiction', 'Seven (a.k.a. Se7en)', 'Star Wars: Episode V - The Empire Strikes Back', 'Star Wars: Episode IV - A New Hope', "Schindler's List", 'Fight Club', 'Terminator 2: Judgment Day', 'Life Is Beautiful (La Vita è bella)', 'American History X'}
# Precision@k: 0.2
# Recall@k: 0.08
# ----------------------------------------
# User: 416
# Relevant Recommendations (top k): {'Pulp Fiction', 'Fight Club'}
# Precision@k: 0.04
# Recall@k: 0.08695652173913043
# ----------------------------------------
# User: 438
# Relevant Recommendations (top k): {'Forrest Gump', 'Memento', 'Star Wars: Episode V - The Empire Strikes Back', 'Gladiator', 'Saving Private Ryan', "Schindler's List"}
# Precision@k: 0.12
# Recall@k: 0.027522935779816515
# ----------------------------------------
# User: 73
# Relevant Recommendations (top k): {'Captain America: The Winter Soldier', 'Memento', 'Thor', 'Interstellar', 'Iron Man', 'Guardians of the Galaxy', 'Avengers: Age of Ultron', 'Saving Private Ryan'}
# Precision@k: 0.16
# Recall@k: 0.06896551724137931
# ----------------------------------------
# User: 567
# Relevant Recommendations (top k): {'12 Angry Men'}
# Precision@k: 0.02
# Recall@k: 0.024390243902439025
# ----------------------------------------
# User: 391
# Relevant Recommendations (top k): {'American Beauty', 'Forrest Gump', 'Pulp Fiction', 'Memento', 'Braveheart', 'Goodfellas', "Schindler's List", 'Terminator 2: Judgment Day', 'Fight Club', 'Léon: The Professional'}
# Precision@k: 0.2
# Recall@k: 0.0411522633744856
# ----------------------------------------
# User: 380
# Relevant Recommendations (top k): {'The Dark Knight', 'Forrest Gump', 'Pulp Fiction', 'Braveheart', 'Avengers: Infinity War', 'Inception', 'Goodfellas', 'Gladiator', 'Saving Private Ryan', 'Spirited Away (Sen to Chihiro no kamikakushi)', 'Fight Club', 'Terminator 2: Judgment Day', 'City of God (Cidade de Deus)'}
# Precision@k: 0.26
# Recall@k: 0.01943198804185351
# ----------------------------------------
# User: 305
# Relevant Recommendations (top k): {'Inception', 'Avengers: Infinity War - Part I', 'Goodfellas', 'Back to the Future', 'Kill Bill: Vol. 2', 'Lord of the Rings: The Two Towers, The', 'Star Wars: Episode V - The Empire Strikes Back', 'Star Wars: Episode IV - A New Hope', '12 Angry Men', 'Saving Private Ryan', "Schindler's List", 'Lord of the Rings: The Fellowship of the Ring, The', 'American Psycho', 'WALL·E', 'Reservoir Dogs', 'Inglourious Basterds', 'Spirited Away (Sen to Chihiro no kamikakushi)', 'American History X', 'Dark Knight, The', 'Star Wars: Episode VI - Return of the Jedi', 'Kill Bill: Vol. 1', 'Forrest Gump', 'Pulp Fiction', 'Lord of the Rings: The Return of the King, The', 'Fight Club', 'Good Will Hunting'}
# Precision@k: 0.52
# Recall@k: 0.06220095693779904
# ----------------------------------------
# User: 409
# Relevant Recommendations (top k): {'Pulp Fiction', 'Goodfellas'}
# Precision@k: 0.04
# Recall@k: 0.023809523809523808
# ----------------------------------------
# User: 307
# Relevant Recommendations (top k): {'Forrest Gump', 'Pulp Fiction', 'Memento', 'Spirited Away', 'Goodfellas', "Schindler's List", 'Fight Club', 'Se7en', 'American History X'}
# Precision@k: 0.18
# Recall@k: 0.0481283422459893
# ----------------------------------------
# User: 274
# Relevant Recommendations (top k): {'Kill Bill: Vol. 1', 'Forrest Gump', 'Pulp Fiction', 'Memento', 'Star Wars: Episode V - The Empire Strikes Back', 'Braveheart', 'Inception', 'Goodfellas', 'Inglourious Basterds', 'Saving Private Ryan', 'Spirited Away (Sen to Chihiro no kamikakushi)', "Schindler's List", 'Léon: The Professional (a.k.a. The Professional) (Léon)', 'Fight Club', 'Terminator 2: Judgment Day', 'Good Will Hunting', 'American History X', 'City of God (Cidade de Deus)'}
# Precision@k: 0.36
# Recall@k: 0.056782334384858045
# ----------------------------------------
# User: 125
# Relevant Recommendations (top k): {'The Dark Knight', 'WALL·E', 'American Beauty', 'Forrest Gump', 'Pulp Fiction', 'Memento', 'Braveheart', 'Up', 'Inception', 'Back to the Future', 'Django Unchained', 'The Martian', 'Fight Club', 'Terminator 2: Judgment Day'}
# Precision@k: 0.28
# Recall@k: 0.05982905982905983
# ----------------------------------------
# User: 561
# Relevant Recommendations (top k): {'Kill Bill: Vol. 1', 'WALL·E', 'Forrest Gump', 'Pulp Fiction', 'Up', 'Goodfellas', 'Back to the Future', 'Gladiator', "Schindler's List", 'Kill Bill: Vol. 2', 'Léon: The Professional (a.k.a. The Professional) (Léon)', 'Fight Club', 'Toy Story', 'Se7en'}
# Precision@k: 0.28
# Recall@k: 0.07692307692307693
# ----------------------------------------
# User: 68
# Relevant Recommendations (top k): {'Memento', 'Star Wars: Episode V - The Empire Strikes Back', 'Inception', 'The Empire Strikes Back', 'Saving Private Ryan', 'Léon: The Professional (a.k.a. The Professional) (Léon)'}
# Precision@k: 0.12
# Recall@k: 0.017094017094017096
# ----------------------------------------
# User: 525
# Relevant Recommendations (top k): {'Avengers, The', 'Raiders of the Lost Ark (Indiana Jones and the Raiders of the Lost Ark)', 'Forrest Gump', 'Memento', 'Star Wars: Episode V - The Empire Strikes Back', 'Interstellar', 'Inception', 'Spirited Away (Sen to Chihiro no kamikakushi)', "Schindler's List", 'Léon: The Professional (a.k.a. The Professional) (Léon)', 'Life Is Beautiful (La Vita è bella)'}
# Precision@k: 0.22
# Recall@k: 0.052132701421800945
# ----------------------------------------
# User: 414
# Relevant Recommendations (top k): {'Inception', 'Goodfellas', 'Casablanca', 'Star Wars: Episode V - The Empire Strikes Back', 'Star Wars: Episode IV - A New Hope', 'Gladiator', 'Saving Private Ryan', "Schindler's List", 'Alien', 'Apocalypse Now', 'Raiders of the Lost Ark (Indiana Jones and the Raiders of the Lost Ark)', 'American Beauty', 'Braveheart', 'Toy Story 2', 'Spirited Away (Sen to Chihiro no kamikakushi)', 'Fargo', 'Forrest Gump', 'Pulp Fiction', 'Memento', 'The Empire Strikes Back', 'Fight Club', 'Terminator 2: Judgment Day', 'Good Will Hunting', 'Die Hard'}
# Precision@k: 0.48
# Recall@k: 0.019559902200488997
# ----------------------------------------
# User: 6
# Relevant Recommendations (top k): {'Se7en', 'Braveheart', 'Forrest Gump'}
# Precision@k: 0.06
# Recall@k: 0.02112676056338028
# ----------------------------------------
# User: 601
# Relevant Recommendations (top k): {'Inception', 'Toy Story', 'Se7en', 'Batman Begins', 'Up', '12 Angry Men', 'Gladiator', 'Saving Private Ryan', "Schindler's List", 'City of God (Cidade de Deus)', 'WALL·E', 'Django Unchained', 'Inglourious Basterds', 'Spirited Away (Sen to Chihiro no kamikakushi)', 'Memento', 'The Godfather', 'Interstellar', 'Fight Club', 'Life Is Beautiful (La Vita è bella)', 'Good Will Hunting'}
# Precision@k: 0.4
# Recall@k: 0.20618556701030927
# ----------------------------------------
# User: 325
# Relevant Recommendations (top k): {'Pulp Fiction', 'Memento'}
# Precision@k: 0.04
# Recall@k: 0.012738853503184714
# ----------------------------------------
# User: 82
# Relevant Recommendations (top k): {'Gladiator', 'Forrest Gump'}
# Precision@k: 0.04
# Recall@k: 0.025
# ----------------------------------------
# User: 16
# Relevant Recommendations (top k): {'Fargo', 'WALL·E', 'Memento', 'Up', '12 Angry Men', 'Spirited Away (Sen to Chihiro no kamikakushi)', "Schindler's List", 'Toy Story'}
# Precision@k: 0.16
# Recall@k: 0.1509433962264151
# ----------------------------------------
# User: 542
# Relevant Recommendations (top k): {'American Beauty', 'Forrest Gump', 'Memento', 'Fight Club', 'Se7en'}
# Precision@k: 0.1
# Recall@k: 0.078125
# ----------------------------------------
# User: 32
# Relevant Recommendations (top k): {'Pulp Fiction', 'Star Wars: Episode V - The Empire Strikes Back', "Schindler's List"}
# Precision@k: 0.06
# Recall@k: 0.05
# ----------------------------------------
# User: 140
# Relevant Recommendations (top k): {'American Beauty', 'Forrest Gump', 'Pulp Fiction', 'Gladiator', 'Saving Private Ryan', "Schindler's List", 'Se7en'}
# Precision@k: 0.14
# Recall@k: 0.02456140350877193
# ----------------------------------------
# User: 182
# Relevant Recommendations (top k): {'Kill Bill: Vol. 1', 'American Beauty', 'Forrest Gump', 'Pulp Fiction', 'Memento', 'Seven (a.k.a. Se7en)', 'Goodfellas', 'Spirited Away (Sen to Chihiro no kamikakushi)', "Schindler's List", 'Fight Club'}
# Precision@k: 0.2
# Recall@k: 0.020491803278688523
# ----------------------------------------
# User: 89
# Relevant Recommendations (top k): {'Life Is Beautiful (La Vita è bella)', 'Up'}
# Precision@k: 0.04
# Recall@k: 0.008130081300813009
# ----------------------------------------
# User: 359
# Relevant Recommendations (top k): {'Pulp Fiction', 'Good Will Hunting', "Schindler's List", 'Silence of the Lambs, The'}
# Precision@k: 0.08
# Recall@k: 0.14285714285714285
# ----------------------------------------
# User: 183
# Relevant Recommendations (top k): {'Saving Private Ryan', 'Terminator 2: Judgment Day'}
# Precision@k: 0.04
# Recall@k: 0.05128205128205128
# ----------------------------------------
# User: 111
# Relevant Recommendations (top k): {'Inception', 'Fight Club', 'Forrest Gump'}
# Precision@k: 0.06
# Recall@k: 0.011764705882352941
# ----------------------------------------
# User: 80
# Relevant Recommendations (top k): {'Iron Man 3', 'Memento', 'Iron Man', 'Inception', 'Fight Club'}
# Precision@k: 0.1
# Recall@k: 0.03289473684210526
# ----------------------------------------
# User: 448
# Relevant Recommendations (top k): {'Fargo', 'Raiders of the Lost Ark (Indiana Jones and the Raiders of the Lost Ark)', 'Kill Bill: Vol. 1', 'Pulp Fiction', 'Memento', 'Star Wars: Episode V - The Empire Strikes Back', 'Inception', 'Goodfellas', 'Back to the Future', 'Gladiator', 'Casablanca', 'Fight Club', 'Good Will Hunting', 'Toy Story', 'Star Wars: Episode VI - Return of the Jedi'}
# Precision@k: 0.3
# Recall@k: 0.03296703296703297
# ----------------------------------------
# User: 514
# Relevant Recommendations (top k): {'Forrest Gump', 'Pulp Fiction', 'Interstellar', 'Inception', 'Goodfellas', 'Inglourious Basterds', 'Shutter Island'}
# Precision@k: 0.14
# Recall@k: 0.037037037037037035
# ----------------------------------------
# User: 509
# Relevant Recommendations (top k): {'Star Wars: Episode V - The Empire Strikes Back', 'Toy Story 3', 'Spirited Away (Sen to Chihiro no kamikakushi)'}
# Precision@k: 0.06
# Recall@k: 0.03488372093023256
# ----------------------------------------
# User: 131
# Relevant Recommendations (top k): {'Fargo', 'Pulp Fiction', 'Memento', 'Inception', 'Goodfellas', 'Léon: The Professional (a.k.a. The Professional) (Léon)', 'City of God (Cidade de Deus)'}
# Precision@k: 0.14
# Recall@k: 0.2413793103448276
# ----------------------------------------
# User: 45
# Relevant Recommendations (top k): {'Forrest Gump', 'Pulp Fiction', 'Gladiator', 'Saving Private Ryan', 'Fight Club', 'Life Is Beautiful (La Vita è bella)', 'Toy Story'}
# Precision@k: 0.14
# Recall@k: 0.025925925925925925
# ----------------------------------------
# User: 156
# Relevant Recommendations (top k): {'Pulp Fiction', 'Memento', 'Goodfellas'}
# Precision@k: 0.06
# Recall@k: 0.013888888888888888
# ----------------------------------------
# User: 440
# Relevant Recommendations (top k): set()
# Precision@k: 0.0
# Recall@k: 0.0
# ----------------------------------------
# User: 312
# Relevant Recommendations (top k): {'Apocalypse Now', 'Forrest Gump', 'Star Wars: Episode V - The Empire Strikes Back', 'Saving Private Ryan', 'Casablanca', "Schindler's List", 'Terminator 2: Judgment Day'}
# Precision@k: 0.14
# Recall@k: 0.05
# ----------------------------------------
# User: 57
# Relevant Recommendations (top k): {'Fargo', 'Forrest Gump', 'Braveheart', 'Gladiator', 'Saving Private Ryan', "Schindler's List", 'Terminator 2: Judgment Day', 'Life Is Beautiful (La Vita è bella)'}
# Precision@k: 0.16
# Recall@k: 0.03347280334728033
# ----------------------------------------
# User: 603
# Relevant Recommendations (top k): {'Pulp Fiction', 'Memento', 'Goodfellas', 'Gladiator', 'Saving Private Ryan', 'Fight Club'}
# Precision@k: 0.12
# Recall@k: 0.010657193605683837
# ----------------------------------------
# User: 337
# Relevant Recommendations (top k): {'Braveheart'}
# Precision@k: 0.02
# Recall@k: 0.01694915254237288
# ----------------------------------------
# User: 116
# Relevant Recommendations (top k): {'Gladiator', 'Terminator 2: Judgment Day', 'Forrest Gump'}
# Precision@k: 0.06
# Recall@k: 0.07692307692307693
# ----------------------------------------
# User: 122
# Relevant Recommendations (top k): {'WALL·E', 'Forrest Gump', 'Pulp Fiction', 'Star Wars: Episode V - The Empire Strikes Back', 'Interstellar', 'Inception', 'Goodfellas', 'Django Unchained', 'Fight Club', 'Terminator 2: Judgment Day'}
# Precision@k: 0.2
# Recall@k: 0.03636363636363636
# ----------------------------------------
# User: 201
# Relevant Recommendations (top k): {'Forrest Gump', 'Pulp Fiction', 'Goodfellas', 'Saving Private Ryan', 'Terminator 2: Judgment Day', 'Life Is Beautiful (La Vita è bella)'}
# Precision@k: 0.12
# Recall@k: 0.06896551724137931
# ----------------------------------------
# User: 167
# Relevant Recommendations (top k): {'Shrek 2', 'Wallace & Gromit in The Curse of the Were-Rabbit', 'Spider-Man 2', 'Harry Potter and the Goblet of Fire', 'V for Vendetta', 'Batman Begins', 'Napoleon Dynamite', 'Pirates of the Caribbean: The Curse of the Black Pearl', 'Shaun of the Dead'}
# Precision@k: 0.18
# Recall@k: 0.11842105263157894
# ----------------------------------------
# User: 139
# Relevant Recommendations (top k): set()
# Precision@k: 0.0
# Recall@k: 0.0
# ----------------------------------------
# User: 450
# Relevant Recommendations (top k): {'Saving Private Ryan', 'Braveheart', 'American Beauty'}
# Precision@k: 0.06
# Recall@k: 0.06976744186046512
# ----------------------------------------
# User: 178
# Relevant Recommendations (top k): {'Forrest Gump', 'Pulp Fiction', 'Memento', 'Braveheart', 'Goodfellas', 'Saving Private Ryan', "Schindler's List", 'Fight Club', 'Terminator 2: Judgment Day', 'Se7en', 'American History X', 'City of God (Cidade de Deus)'}
# Precision@k: 0.24
# Recall@k: 0.2
# ----------------------------------------
# User: 581
# Relevant Recommendations (top k): {'Eternal Sunshine of the Spotless Mind', 'Forrest Gump', 'Memento', 'Interstellar', 'Inception', "Schindler's List", 'Fight Club', 'Life Is Beautiful (La Vita è bella)'}
# Precision@k: 0.16
# Recall@k: 0.22857142857142856
# ----------------------------------------
# User: 215
# Relevant Recommendations (top k): {'Raiders of the Lost Ark (Indiana Jones and the Raiders of the Lost Ark)', 'American Beauty', 'Memento', 'Star Wars: Episode V - The Empire Strikes Back', 'Star Wars: Episode IV - A New Hope', '12 Angry Men', 'Amadeus', 'Casablanca', "Schindler's List", 'Fight Club', 'Life Is Beautiful (La Vita è bella)', 'Good Will Hunting'}
# Precision@k: 0.24
# Recall@k: 0.18461538461538463
# ----------------------------------------
# User: 610
# Relevant Recommendations (top k): {'Avengers, The', 'Inception', 'Goodfellas', 'Back to the Future', 'Lord of the Rings: The Two Towers, The', 'Toy Story', 'Matrix, The', 'Star Wars: Episode V - The Empire Strikes Back', 'Star Wars: Episode IV - A New Hope', 'Gladiator', 'Saving Private Ryan', 'Dark Knight Rises, The', 'Terminator, The', 'Alien', 'Silence of the Lambs, The', 'City of God (Cidade de Deus)', 'Lord of the Rings: The Fellowship of the Ring, The', 'Taxi Driver', 'Raiders of the Lost Ark (Indiana Jones and the Raiders of the Lost Ark)', 'Braveheart', 'Spirited Away (Sen to Chihiro no kamikakushi)', 'Terminator 2: Judgment Day', 'Good, the Bad and the Ugly, The (Buono, il brutto, il cattivo, Il)', 'Star Wars: Episode VI - Return of the Jedi', 'Godfather, The', 'Fargo', 'Pulp Fiction', 'Memento', 'Seven (a.k.a. Se7en)', 'Psycho', 'Lord of the Rings: The Return of the King, The', 'Fight Club', 'Usual Suspects, The', 'Princess Bride, The', 'Die Hard'}
# Precision@k: 0.7
# Recall@k: 0.057003257328990226
# ----------------------------------------
# User: 81
# Relevant Recommendations (top k): set()
# Precision@k: 0.0
# Recall@k: 0.0
# ----------------------------------------
# User: 340
# Relevant Recommendations (top k): {'Pulp Fiction'}
# Precision@k: 0.02
# Recall@k: 0.041666666666666664
# ----------------------------------------
# User: 323
# Relevant Recommendations (top k): {'Pulp Fiction', "Schindler's List"}
# Precision@k: 0.04
# Recall@k: 0.08333333333333333
# ----------------------------------------
# User: 232
# Relevant Recommendations (top k): {'Inception'}
# Precision@k: 0.02
# Recall@k: 0.0045871559633027525
# ----------------------------------------
# User: 186
# Relevant Recommendations (top k): {'Raiders of the Lost Ark (Indiana Jones and the Raiders of the Lost Ark)', "One Flew Over the Cuckoo's Nest", 'Star Wars: Episode V - The Empire Strikes Back', 'Seven', 'Gladiator', 'Terminator 2: Judgment Day', 'Life Is Beautiful (La Vita è bella)'}
# Precision@k: 0.14
# Recall@k: 0.035175879396984924
# ----------------------------------------
# User: 28
# Relevant Recommendations (top k): {'WALL·E', 'Forrest Gump', 'Pulp Fiction', 'Batman Begins', 'Goodfellas', 'Gladiator', 'The Empire Strikes Back', 'Léon: The Professional (a.k.a. The Professional) (Léon)', 'Terminator 2: Judgment Day'}
# Precision@k: 0.18
# Recall@k: 0.08035714285714286
# ----------------------------------------
# User: 195
# Relevant Recommendations (top k): {'Apollo 13', 'Pulp Fiction', 'Star Wars: Episode V - The Empire Strikes Back', 'Star Wars: Episode IV - A New Hope', 'Gladiator', "Schindler's List", 'Good Will Hunting', 'American History X'}
# Precision@k: 0.16
# Recall@k: 0.07339449541284404
# ----------------------------------------
# User: 596
# Relevant Recommendations (top k): {'Iron Man 3', 'Ant-Man', 'Captain America: The Winter Soldier', 'Guardians of the Galaxy 2', 'Black Panther', 'Ant-Man and the Wasp', 'Guardians of the Galaxy', 'Inception', 'Avengers: Infinity War - Part I', 'Harry Potter and the Deathly Hallows: Part 1', 'Star Trek Beyond', 'The Martian', 'Thor: Ragnarok', 'Star Trek'}
# Precision@k: 0.28
# Recall@k: 0.0958904109589041
# ----------------------------------------
# User: 602
# Relevant Recommendations (top k): {'Pulp Fiction', "Schindler's List", 'Terminator 2: Judgment Day'}
# Precision@k: 0.06
# Recall@k: 0.05555555555555555
# ----------------------------------------
# User: 202
# Relevant Recommendations (top k): {'Being John Malkovich', 'Fargo', 'American Beauty', 'Forrest Gump', 'Pulp Fiction', 'Braveheart', 'Shakespeare in Love', 'Saving Private Ryan', 'Eyes Wide Shut', 'Fight Club', 'Léon: The Professional', 'L.A. Confidential'}
# Precision@k: 0.24
# Recall@k: 0.042105263157894736
# ----------------------------------------
# User: 200
# Relevant Recommendations (top k): {'Forrest Gump', 'Pulp Fiction', 'Memento', 'Batman Begins', 'Iron Man', 'Goodfellas', "Pirates of the Caribbean: Dead Man's Chest", 'Gladiator', 'Pirates of the Caribbean: The Curse of the Black Pearl', 'Fight Club', 'Se7en'}
# Precision@k: 0.22
# Recall@k: 0.054455445544554455
# ----------------------------------------
# User: 387
# Relevant Recommendations (top k): {'Fargo', 'Raiders of the Lost Ark (Indiana Jones and the Raiders of the Lost Ark)', 'Forrest Gump', 'Pulp Fiction', 'Memento', 'Star Wars: Episode V - The Empire Strikes Back', 'Batman Begins', 'Star Wars: Episode IV - A New Hope', 'Alien', 'The Empire Strikes Back', 'Spirited Away (Sen to Chihiro no kamikakushi)', 'Fight Club', 'Life Is Beautiful (La Vita è bella)', 'American History X'}
# Precision@k: 0.28
# Recall@k: 0.04487179487179487
# ----------------------------------------
# User: 510
# Relevant Recommendations (top k): set()
# Precision@k: 0.0
# Recall@k: 0.0
# ----------------------------------------
# User: 290
# Relevant Recommendations (top k): {'Pulp Fiction', 'Star Wars: Episode V - The Empire Strikes Back', "Schindler's List", 'Goodfellas'}
# Precision@k: 0.08
# Recall@k: 0.017167381974248927
# ----------------------------------------
# User: 221
# Relevant Recommendations (top k): {'American Beauty', 'Pulp Fiction', '12 Angry Men', 'Goodfellas', 'Fight Club'}
# Precision@k: 0.1
# Recall@k: 0.0196078431372549
# ----------------------------------------
# User: 598
# Relevant Recommendations (top k): {'Inception'}
# Precision@k: 0.02
# Recall@k: 0.06666666666666667
# ----------------------------------------
# User: 34
# Relevant Recommendations (top k): {'Kill Bill: Vol. 1', 'Forrest Gump', 'Memento', 'Kill Bill: Vol. 2', 'Fight Club'}
# Precision@k: 0.1
# Recall@k: 0.11363636363636363
# ----------------------------------------
# User: 62
# Relevant Recommendations (top k): {'Looper', 'Fracture', 'Harry Potter and the Order of the Phoenix', 'The Hunger Games: Catching Fire', 'Minority Report', 'Titanic', 'Up', 'Gladiator', 'Star Wars: Episode III - Revenge of the Sith', 'Primer', "Pirates of the Caribbean: At World's End", 'Deadpool', 'WALL·E', 'Reservoir Dogs', 'Superbad', 'Thor: Ragnarok', 'Nightcrawler', 'Enemy at the Gates', 'Kill Bill: Vol. 1', 'Spider-Man 3', 'What If', 'Oblivion', 'Léon: The Professional (a.k.a. The Professional) (Léon)', 'Fight Club', 'Good Will Hunting', '3:10 to Yuma'}
# Precision@k: 0.52
# Recall@k: 0.0931899641577061
# ----------------------------------------
# User: 137
# Relevant Recommendations (top k): {'Saving Private Ryan', 'Braveheart', '12 Angry Men'}
# Precision@k: 0.06
# Recall@k: 0.033707865168539325
# ----------------------------------------
# User: 606
# Relevant Recommendations (top k): {"One Flew Over the Cuckoo's Nest", 'City Lights', 'Casablanca', 'Rear Window', "Singin' in the Rain", 'Star Wars: Episode V - The Empire Strikes Back', 'Star Wars: Episode IV - A New Hope', 'Saving Private Ryan', "Schindler's List", 'Apocalypse Now', 'Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb', 'Seven Samurai (Shichinin no samurai)', 'Spirited Away (Sen to Chihiro no kamikakushi)', 'American History X', 'Star Wars: Episode VI - Return of the Jedi', 'Forrest Gump', 'Pulp Fiction', 'Memento', 'Some Like It Hot', 'Léon: The Professional (a.k.a. The Professional) (Léon)', 'Fight Club'}
# Precision@k: 0.42
# Recall@k: 0.03425774877650897
# ----------------------------------------
# User: 352
# Relevant Recommendations (top k): {'Prisoners', 'WALL·E', 'Forrest Gump', 'Pulp Fiction', 'Memento', 'Interstellar', 'Inception', 'Django Unchained', 'Gladiator', 'Saving Private Ryan', 'Inglourious Basterds', "Schindler's List", 'Fight Club', 'Whiplash', 'American History X'}
# Precision@k: 0.3
# Recall@k: 0.08522727272727272
# ----------------------------------------
# User: 572
# Relevant Recommendations (top k): {'Saving Private Ryan', 'Star Wars: Episode V - The Empire Strikes Back', "Schindler's List", 'Forrest Gump'}
# Precision@k: 0.08
# Recall@k: 0.03305785123966942
# ----------------------------------------
# User: 129
# Relevant Recommendations (top k): {'Braveheart', 'Batman Begins', 'Star Wars: Episode IV - A New Hope', 'Gladiator', 'Saving Private Ryan', 'Spirited Away (Sen to Chihiro no kamikakushi)', 'The Empire Strikes Back', 'Fight Club'}
# Precision@k: 0.16
# Recall@k: 0.08421052631578947
# ----------------------------------------
# User: 279
# Relevant Recommendations (top k): {'Pulp Fiction', 'Star Wars: Episode V - The Empire Strikes Back', 'Interstellar', 'Braveheart', 'Inception', 'Django Unchained', 'Inglourious Basterds', 'Saving Private Ryan', 'Lord of the Rings: The Two Towers, The', 'Terminator 2: Judgment Day', 'Alien', 'Shutter Island'}
# Precision@k: 0.24
# Recall@k: 0.1411764705882353
# ----------------------------------------
# User: 428
# Relevant Recommendations (top k): {'Pulp Fiction', 'Alien', 'Fight Club'}
# Precision@k: 0.06
# Recall@k: 0.07142857142857142
# ----------------------------------------
# User: 152
# Relevant Recommendations (top k): {'North by Northwest', 'American Beauty', 'Pulp Fiction', '12 Angry Men', 'Goodfellas', "Schindler's List", 'Fight Club', 'Rear Window'}
# Precision@k: 0.16
# Recall@k: 0.18181818181818182
# ----------------------------------------
# User: 328
# Relevant Recommendations (top k): set()
# Precision@k: 0.0
# Recall@k: 0.0
# ----------------------------------------
# User: 427
# Relevant Recommendations (top k): {'Pulp Fiction', 'Braveheart', 'Memento', 'Gladiator'}
# Precision@k: 0.08
# Recall@k: 0.14814814814814814
# ----------------------------------------
# User: 367
# Relevant Recommendations (top k): {'Star Wars: Episode V - The Empire Strikes Back', 'Raiders of the Lost Ark (Indiana Jones and the Raiders of the Lost Ark)', 'Back to the Future', 'Forrest Gump'}
# Precision@k: 0.08
# Recall@k: 0.03076923076923077
# ----------------------------------------
# User: 560
# Relevant Recommendations (top k): {'WALL·E', 'Pulp Fiction', 'Braveheart', 'Inception', 'Gladiator', 'Spirited Away (Sen to Chihiro no kamikakushi)', 'Léon: The Professional (a.k.a. The Professional) (Léon)', 'Fight Club', 'American History X'}
# Precision@k: 0.18
# Recall@k: 0.04285714285714286
# ----------------------------------------
# User: 19
# Relevant Recommendations (top k): {'Star Wars: Episode V - The Empire Strikes Back', 'Fight Club', 'Terminator 2: Judgment Day'}
# Precision@k: 0.06
# Recall@k: 0.02857142857142857
# ----------------------------------------
# User: 474
# Relevant Recommendations (top k): {'Pulp Fiction', 'Memento', 'Star Wars: Episode V - The Empire Strikes Back', '12 Angry Men', 'Spirited Away (Sen to Chihiro no kamikakushi)', "Schindler's List", 'Fight Club', 'Life Is Beautiful (La Vita è bella)', 'American History X', 'City of God (Cidade de Deus)'}
# Precision@k: 0.2
# Recall@k: 0.012706480304955527
# ----------------------------------------
# User: 189
# Relevant Recommendations (top k): {"Schindler's List", 'Inception', 'Fight Club', 'Forrest Gump'}
# Precision@k: 0.08
# Recall@k: 0.2222222222222222
# ----------------------------------------
# User: 556
# Relevant Recommendations (top k): {'Alice in Wonderland', "Pan's Labyrinth"}
# Precision@k: 0.04
# Recall@k: 0.07407407407407407
# ----------------------------------------
# User: 3
# Relevant Recommendations (top k): set()
# Precision@k: 0.0
# Recall@k: 0.0
# ----------------------------------------
# User: 1
# Relevant Recommendations (top k): set()
# Precision@k: 0.0
# Recall@k: 0.0
# ----------------------------------------
# User: 217
# Relevant Recommendations (top k): {'Fargo', 'Star Wars: Episode I - The Phantom Menace', 'Star Wars: Episode V - The Empire Strikes Back', 'Star Wars: Episode IV - A New Hope', 'Toy Story 2', 'Saving Private Ryan', 'Raiders of the Lost Ark'}
# Precision@k: 0.14
# Recall@k: 0.07142857142857142
# ----------------------------------------
# User: 282
# Relevant Recommendations (top k): {'Forrest Gump', 'Pulp Fiction', 'Memento', 'Inception', 'Goodfellas', '12 Angry Men', 'Gladiator', 'Saving Private Ryan', "Schindler's List", 'Fight Club', 'Good Will Hunting', 'American History X'}
# Precision@k: 0.24
# Recall@k: 0.06557377049180328
# ----------------------------------------
# User: 310
# Relevant Recommendations (top k): {'Raiders of the Lost Ark'}
# Precision@k: 0.02
# Recall@k: 0.02564102564102564
# ----------------------------------------
# User: 91
# Relevant Recommendations (top k): {'Raiders of the Lost Ark (Indiana Jones and the Raiders of the Lost Ark)', 'Pulp Fiction', 'Memento', 'Star Wars: Episode IV - A New Hope', 'Goodfellas', 'Saving Private Ryan', 'Spirited Away (Sen to Chihiro no kamikakushi)', 'Casablanca', 'Fight Club', 'Terminator 2: Judgment Day', 'Toy Story'}
# Precision@k: 0.22
# Recall@k: 0.046218487394957986
# ----------------------------------------
# User: 103
# Relevant Recommendations (top k): {'Fargo', 'Forrest Gump', 'Pulp Fiction', 'Memento', 'Braveheart', 'Interstellar', 'Inception', 'Goodfellas', 'Saving Private Ryan', 'Spirited Away (Sen to Chihiro no kamikakushi)', 'Fight Club', 'Good Will Hunting', 'American History X', 'City of God (Cidade de Deus)'}
# Precision@k: 0.28
# Recall@k: 0.05761316872427984
# ----------------------------------------
# User: 566
# Relevant Recommendations (top k): {'Pulp Fiction', 'Braveheart', "Schindler's List", 'Forrest Gump'}
# Precision@k: 0.08
# Recall@k: 0.09523809523809523
# ----------------------------------------
# User: 298
# Relevant Recommendations (top k): {'Raiders of the Lost Ark (Indiana Jones and the Raiders of the Lost Ark)', 'Pulp Fiction', 'Star Wars: Episode V - The Empire Strikes Back', 'Star Wars: Episode IV - A New Hope', 'Goodfellas', 'Spirited Away (Sen to Chihiro no kamikakushi)', 'Fight Club', 'Terminator 2: Judgment Day', 'Aliens', 'Star Wars: Episode VI - Return of the Jedi'}
# Precision@k: 0.2
# Recall@k: 0.11764705882352941
# ----------------------------------------
# User: 381
# Relevant Recommendations (top k): {'Forrest Gump', 'Memento', 'Spirited Away (Sen to Chihiro no kamikakushi)', 'Fight Club', 'American History X'}
# Precision@k: 0.1
# Recall@k: 0.023148148148148147
# ----------------------------------------
# User: 292
# Relevant Recommendations (top k): {'Saving Private Ryan', '12 Angry Men', 'Forrest Gump'}
# Precision@k: 0.06
# Recall@k: 0.015957446808510637
# ----------------------------------------
# User: 43
# Relevant Recommendations (top k): {'Seven (a.k.a. Se7en)', 'Terminator 2: Judgment Day', 'Forrest Gump'}
# Precision@k: 0.06
# Recall@k: 0.029411764705882353
# ----------------------------------------
# User: 50
# Relevant Recommendations (top k): {'Pulp Fiction', 'Spirited Away (Sen to Chihiro no kamikakushi)'}
# Precision@k: 0.04
# Recall@k: 0.05263157894736842
# ----------------------------------------
# User: 46
# Relevant Recommendations (top k): {'Braveheart', 'Silence of the Lambs, The', 'Die Hard'}
# Precision@k: 0.06
# Recall@k: 0.1111111111111111
# ----------------------------------------
# User: 564
# Relevant Recommendations (top k): set()
# Precision@k: 0.0
# Recall@k: 0.0
# ----------------------------------------
# User: 382
# Relevant Recommendations (top k): {'Raiders of the Lost Ark (Indiana Jones and the Raiders of the Lost Ark)', 'WALL·E', 'Forrest Gump', 'Pulp Fiction', 'Memento', 'Star Wars: Episode V - The Empire Strikes Back', 'Psycho', 'Titanic', 'Inception', 'Saving Private Ryan', 'Casablanca', "Schindler's List", 'Fight Club', 'Alien'}
# Precision@k: 0.28
# Recall@k: 0.12844036697247707
# ----------------------------------------
# User: 48
# Relevant Recommendations (top k): set()
# Precision@k: 0.0
# Recall@k: 0.0
# ----------------------------------------
# User: 338
# Relevant Recommendations (top k): {'Kill Bill: Vol. 1', 'Pulp Fiction', '12 Angry Men', "Schindler's List", 'Fight Club'}
# Precision@k: 0.1
# Recall@k: 0.3333333333333333
# ----------------------------------------
# User: 475
# Relevant Recommendations (top k): {'Star Wars: Episode V - The Empire Strikes Back', 'Interstellar', 'Batman Begins', 'Gladiator', 'Spirited Away (Sen to Chihiro no kamikakushi)', 'Terminator 2: Judgment Day'}
# Precision@k: 0.12
# Recall@k: 0.043795620437956206
# ----------------------------------------
# User: 7
# Relevant Recommendations (top k): {'Star Wars: Episode V - The Empire Strikes Back', 'Spirited Away (Sen to Chihiro no kamikakushi)', 'Forrest Gump'}
# Precision@k: 0.06
# Recall@k: 0.04285714285714286
# ----------------------------------------
# User: 469
# Relevant Recommendations (top k): {'Pulp Fiction', 'Goodfellas', 'Saving Private Ryan', "Schindler's List", 'Léon: The Professional (a.k.a. The Professional) (Léon)', 'Terminator 2: Judgment Day', 'Se7en'}
# Precision@k: 0.14
# Recall@k: 0.02631578947368421
# ----------------------------------------
# User: 256
# Relevant Recommendations (top k): {'Inglourious Basterds', 'Up', 'Interstellar', 'WALL·E'}
# Precision@k: 0.08
# Recall@k: 0.031007751937984496
# ----------------------------------------
# User: 132
# Relevant Recommendations (top k): {'American Beauty', 'Forrest Gump', 'Pulp Fiction', 'Memento', 'Psycho', 'Léon: The Professional (a.k.a. The Professional) (Léon)', 'Fight Club'}
# Precision@k: 0.14
# Recall@k: 0.10144927536231885
# ----------------------------------------
# User: 480
# Relevant Recommendations (top k): {'Fargo', 'Forrest Gump', 'Pulp Fiction', 'Memento', 'Star Wars: Episode V - The Empire Strikes Back', 'Braveheart', '12 Angry Men', 'Goodfellas', 'Gladiator', 'Saving Private Ryan', "Schindler's List", 'Léon: The Professional (a.k.a. The Professional) (Léon)', 'Fight Club', 'Terminator 2: Judgment Day', 'Good Will Hunting', 'American History X'}
# Precision@k: 0.32
# Recall@k: 0.05177993527508091
# ----------------------------------------
# User: 227
# Relevant Recommendations (top k): {'The Dark Knight', 'Kill Bill: Vol. 1', 'Forrest Gump', 'Pulp Fiction', "Schindler's List", 'Fight Club'}
# Precision@k: 0.12
# Recall@k: 0.07792207792207792
# ----------------------------------------
# User: 226
# Relevant Recommendations (top k): {'Fargo', 'Forrest Gump', 'Pulp Fiction', 'Gladiator', 'Fight Club', 'Terminator 2: Judgment Day', 'Good Will Hunting', 'American History X'}
# Precision@k: 0.16
# Recall@k: 0.0321285140562249
# ----------------------------------------
# User: 368
# Relevant Recommendations (top k): {'Raiders of the Lost Ark (Indiana Jones and the Raiders of the Lost Ark)', "One Flew Over the Cuckoo's Nest", 'Forrest Gump', 'Pulp Fiction', 'Goodfellas', 'Saving Private Ryan', "Schindler's List", 'Léon: The Professional (a.k.a. The Professional) (Léon)'}
# Precision@k: 0.16
# Recall@k: 0.09876543209876543
# ----------------------------------------
# User: 587
# Relevant Recommendations (top k): {'Pulp Fiction', 'Life Is Beautiful (La Vita è bella)', 'Forrest Gump'}
# Precision@k: 0.06
# Recall@k: 0.022058823529411766
# ----------------------------------------
# User: 488
# Relevant Recommendations (top k): {'Life Is Beautiful (La Vita è bella)', 'Fargo', "Schindler's List", 'Up'}
# Precision@k: 0.08
# Recall@k: 0.05714285714285714
# ----------------------------------------
# User: 135
# Relevant Recommendations (top k): {'Fargo', 'American Beauty', 'Pulp Fiction', 'Memento', 'Braveheart', '12 Angry Men', 'Goodfellas', 'Saving Private Ryan', "Schindler's List", 'Fight Club', 'Terminator 2: Judgment Day', 'Se7en'}
# Precision@k: 0.24
# Recall@k: 0.06857142857142857
# ----------------------------------------
# User: 535
# Relevant Recommendations (top k): {'American Beauty'}
# Precision@k: 0.02
# Recall@k: 0.1111111111111111
# ----------------------------------------
# User: 529
# Relevant Recommendations (top k): set()
# Precision@k: 0.0
# Recall@k: 0.0
# ----------------------------------------
# User: 14
# Relevant Recommendations (top k): {'Se7en', 'Braveheart', 'Forrest Gump'}
# Precision@k: 0.06
# Recall@k: 0.14285714285714285
# ----------------------------------------
# User: 534
# Relevant Recommendations (top k): {'Kill Bill: Vol. 1', 'Forrest Gump', 'Star Wars: Episode V - The Empire Strikes Back', 'Up', 'Inception', 'Gladiator', 'Saving Private Ryan', 'Inglourious Basterds', 'Life Is Beautiful (La Vita è bella)', 'American History X'}
# Precision@k: 0.2
# Recall@k: 0.03058103975535168
# ----------------------------------------
# User: 29
# Relevant Recommendations (top k): {'Gladiator', 'Saving Private Ryan', 'Goodfellas', 'Forrest Gump'}
# Precision@k: 0.08
# Recall@k: 0.05970149253731343
# ----------------------------------------
# User: 21
# Relevant Recommendations (top k): {'Forrest Gump'}
# Precision@k: 0.02
# Recall@k: 0.006993006993006993
# ----------------------------------------
# User: 112
# Relevant Recommendations (top k): {'Raiders of the Lost Ark (Indiana Jones and the Raiders of the Lost Ark)', 'Star Wars: Episode V - The Empire Strikes Back', 'Interstellar', 'Inception', 'Saving Private Ryan', 'Se7en'}
# Precision@k: 0.12
# Recall@k: 0.14634146341463414
# ----------------------------------------
# User: 502
# Relevant Recommendations (top k): set()
# Precision@k: 0.0
# Recall@k: 0.0
# ----------------------------------------
# User: 339
# Relevant Recommendations (top k): {'Inception', 'Goodfellas', 'Back to the Future', 'Lord of the Rings: The Two Towers, The', 'Toy Story', 'Up', '12 Angry Men', 'Gladiator', 'Saving Private Ryan', "Schindler's List", 'City of God (Cidade de Deus)', 'Raiders of the Lost Ark (Indiana Jones and the Raiders of the Lost Ark)', 'WALL·E', 'Spirited Away (Sen to Chihiro no kamikakushi)', 'Fargo', 'Forrest Gump', 'Memento', 'Seven (a.k.a. Se7en)', 'Interstellar', 'Finding Nemo', 'Lord of the Rings: The Return of the King, The', 'Fight Club', 'Shutter Island'}
# Precision@k: 0.46
# Recall@k: 0.08679245283018867
# ----------------------------------------
# User: 27
# Relevant Recommendations (top k): {'Star Wars: Episode V - The Empire Strikes Back', 'Forrest Gump'}
# Precision@k: 0.04
# Recall@k: 0.024390243902439025
# ----------------------------------------
# User: 608
# Relevant Recommendations (top k): {'Pulp Fiction', 'Memento', 'Seven (a.k.a. Se7en)', 'Goodfellas', 'Gladiator', 'Saving Private Ryan', 'The Empire Strikes Back', "Schindler's List", 'Fight Club'}
# Precision@k: 0.18
# Recall@k: 0.03214285714285714
# ----------------------------------------
# User: 187
# Relevant Recommendations (top k): {'Fargo', 'Pulp Fiction', 'Memento', '12 Angry Men', 'Spirited Away (Sen to Chihiro no kamikakushi)', "Schindler's List", 'Casablanca', 'Se7en'}
# Precision@k: 0.16
# Recall@k: 0.04395604395604396
# ----------------------------------------
# User: 551
# Relevant Recommendations (top k): {'WALL·E', 'Forrest Gump', 'Up', 'Inception', 'Finding Nemo', 'Saving Private Ryan', 'Fight Club', 'Good Will Hunting'}
# Precision@k: 0.16
# Recall@k: 0.09302325581395349
# ----------------------------------------
# User: 285
# Relevant Recommendations (top k): {'Pulp Fiction'}
# Precision@k: 0.02
# Recall@k: 0.041666666666666664
# ----------------------------------------
# User: 370
# Relevant Recommendations (top k): {'Pulp Fiction', 'Spirited Away (Sen to Chihiro no kamikakushi)', 'American History X', 'Fight Club'}
# Precision@k: 0.08
# Recall@k: 0.08888888888888889
# ----------------------------------------
# User: 481
# Relevant Recommendations (top k): set()
# Precision@k: 0.0
# Recall@k: 0.0
# ----------------------------------------
# User: 379
# Relevant Recommendations (top k): {'Braveheart', 'Terminator 2: Judgment Day', 'Forrest Gump'}
# Precision@k: 0.06
# Recall@k: 0.2
# ----------------------------------------
# User: 212
# Relevant Recommendations (top k): {"Howl's Moving Castle (Hauru no ugoku shiro)", 'Princess Mononoke (Mononoke-hime)', 'Spirited Away (Sen to Chihiro no kamikakushi)', 'Fight Club', 'My Neighbor Totoro (Tonari no Totoro)', 'Grave of the Fireflies (Hotaru no haka)'}
# Precision@k: 0.12
# Recall@k: 0.05172413793103448
# ----------------------------------------
# User: 160
# Relevant Recommendations (top k): {'Pulp Fiction', 'Star Wars: Episode V - The Empire Strikes Back', 'Braveheart', 'Goodfellas', 'Gladiator', 'Saving Private Ryan', "Schindler's List", 'Fight Club', 'Life Is Beautiful (La Vita è bella)'}
# Precision@k: 0.18
# Recall@k: 0.05844155844155844
# ----------------------------------------
# User: 121
# Relevant Recommendations (top k): {'Pulp Fiction', 'Braveheart', 'Forrest Gump'}
# Precision@k: 0.06
# Recall@k: 0.14285714285714285
# ----------------------------------------
# User: 437
# Relevant Recommendations (top k): {'Apocalypse Now', 'Fargo', 'Pulp Fiction', 'Braveheart', 'Goodfellas', 'Back to the Future', "Schindler's List", 'Se7en'}
# Precision@k: 0.16
# Recall@k: 0.10810810810810811
# ----------------------------------------
# User: 577
# Relevant Recommendations (top k): {'Forrest Gump', 'Braveheart', '12 Angry Men', 'Goodfellas', 'Saving Private Ryan', "Schindler's List"}
# Precision@k: 0.12
# Recall@k: 0.07407407407407407
# ----------------------------------------
# User: 562
# Relevant Recommendations (top k): {'Forrest Gump', 'Pulp Fiction', 'Psycho', 'Inglourious Basterds', 'Spirited Away (Sen to Chihiro no kamikakushi)', "Schindler's List", 'Fight Club'}
# Precision@k: 0.14
# Recall@k: 0.04216867469879518
# ----------------------------------------
# User: 477
# Relevant Recommendations (top k): {'Fargo', 'WALL·E', 'Forrest Gump', 'Pulp Fiction', 'Memento', 'Up', 'Inception', '12 Angry Men', 'Saving Private Ryan', 'Spirited Away (Sen to Chihiro no kamikakushi)', "Schindler's List", 'Terminator 2: Judgment Day', 'Life Is Beautiful (La Vita è bella)', 'Avatar'}
# Precision@k: 0.28
# Recall@k: 0.03674540682414698
# ----------------------------------------
# User: 213
# Relevant Recommendations (top k): {'12 Angry Men'}
# Precision@k: 0.02
# Recall@k: 0.02
# ----------------------------------------
# User: 590
# Relevant Recommendations (top k): {'Forrest Gump', 'Pulp Fiction', 'Braveheart', '12 Angry Men', 'Goodfellas', 'Gladiator', 'Saving Private Ryan', 'Inglourious Basterds', "Schindler's List", 'Life Is Beautiful (La Vita è bella)'}
# Precision@k: 0.2
# Recall@k: 0.0398406374501992
# ----------------------------------------
# User: 259
# Relevant Recommendations (top k): set()
# Precision@k: 0.0
# Recall@k: 0.0
# ----------------------------------------
# User: 222
# Relevant Recommendations (top k): {'The Dark Knight', 'Forrest Gump', 'Pulp Fiction', 'Braveheart', 'Goodfellas', 'Django Unchained', 'Gladiator', 'Inglourious Basterds', 'Se7en'}
# Precision@k: 0.18
# Recall@k: 0.13432835820895522
# ----------------------------------------
# User: 105
# Relevant Recommendations (top k): {'Pulp Fiction', 'Interstellar', 'Spirited Away', 'Inception', 'Goodfellas', '12 Angry Men', 'Saving Private Ryan', 'Gladiator', 'There Will Be Blood', 'Fight Club', 'Terminator 2: Judgment Day', 'City of God (Cidade de Deus)'}
# Precision@k: 0.24
# Recall@k: 0.021660649819494584
# ----------------------------------------
# User: 309
# Relevant Recommendations (top k): {'Life Is Beautiful (La Vita è bella)', 'Saving Private Ryan', "Schindler's List", '12 Angry Men'}
# Precision@k: 0.08
# Recall@k: 0.05555555555555555
# ----------------------------------------
# User: 246
# Relevant Recommendations (top k): {'WALL·E', 'Pulp Fiction', 'Memento', 'Up', 'Inception', 'Spirited Away', 'Finding Nemo', 'Iron Man', 'Léon: The Professional (a.k.a. The Professional) (Léon)', 'Fight Club'}
# Precision@k: 0.2
# Recall@k: 0.06060606060606061
# ----------------------------------------
# User: 248
# Relevant Recommendations (top k): {'Guardians of the Galaxy'}
# Precision@k: 0.02
# Recall@k: 0.04
# ----------------------------------------
# User: 332
# Relevant Recommendations (top k): {'Kill Bill: Vol. 1', 'Forrest Gump', 'Pulp Fiction', 'Memento', 'Batman Begins', 'Inception', 'Goodfellas', '12 Angry Men', 'Saving Private Ryan', "Schindler's List", 'Fight Club'}
# Precision@k: 0.22
# Recall@k: 0.08870967741935484
# ----------------------------------------
# User: 303
# Relevant Recommendations (top k): set()
# Precision@k: 0.0
# Recall@k: 0.0
# ----------------------------------------
# User: 600
# Relevant Recommendations (top k): {'Fargo', 'Forrest Gump', 'Pulp Fiction', 'Memento', 'Star Wars: Episode V - The Empire Strikes Back', 'Star Wars: Episode IV - A New Hope', 'Spirited Away (Sen to Chihiro no kamikakushi)', 'Fight Club', 'Life Is Beautiful (La Vita è bella)', 'Se7en', 'Monty Python and the Holy Grail', 'American History X', 'Raiders of the Lost Ark'}
# Precision@k: 0.26
# Recall@k: 0.06735751295336788
# ----------------------------------------
# User: 489
# Relevant Recommendations (top k): {'Avengers, The', 'American Beauty', 'Forrest Gump', 'Pulp Fiction', 'Memento', 'Braveheart', 'Eternal Sunshine of the Spotless Mind', 'Inception', 'Spirited Away (Sen to Chihiro no kamikakushi)', 'Lord of the Rings: The Return of the King, The', 'Fight Club', 'Life Is Beautiful (La Vita è bella)'}
# Precision@k: 0.24
# Recall@k: 0.06060606060606061
# ----------------------------------------
# User: 306
# Relevant Recommendations (top k): set()
# Precision@k: 0.0
# Recall@k: 0.0
# ----------------------------------------
# User: 4
# Relevant Recommendations (top k): {'Fargo', 'American Beauty', 'Star Wars: Episode IV - A New Hope', '12 Angry Men', 'Goodfellas', 'The Empire Strikes Back'}
# Precision@k: 0.12
# Recall@k: 0.046875
# ----------------------------------------
# User: 58
# Relevant Recommendations (top k): {'Forrest Gump', 'Pulp Fiction', 'Braveheart', "Schindler's List", 'Terminator 2: Judgment Day', 'Se7en', 'Léon: The Professional'}
# Precision@k: 0.14
# Recall@k: 0.1
# ----------------------------------------
# User: 76
# Relevant Recommendations (top k): {'Pulp Fiction', 'Memento', 'Inception', 'Goodfellas', 'Django Unchained', 'Inglourious Basterds', 'Fight Club'}
# Precision@k: 0.14
# Recall@k: 0.15217391304347827
# ----------------------------------------
# User: 418
# Relevant Recommendations (top k): {'Forrest Gump', 'Pulp Fiction', 'Inception', "Schindler's List", 'Fight Club'}
# Precision@k: 0.1
# Recall@k: 0.08064516129032258
# ----------------------------------------
# User: 64
# Relevant Recommendations (top k): {'Forrest Gump', 'Pulp Fiction', 'Memento', '12 Angry Men', 'Goodfellas', 'Saving Private Ryan', "Schindler's List", 'Fight Club', 'Life Is Beautiful (La Vita è bella)', 'American History X'}
# Precision@k: 0.2
# Recall@k: 0.03676470588235294
# ----------------------------------------
# User: 457
# Relevant Recommendations (top k): {'Fight Club'}
# Precision@k: 0.02
# Recall@k: 0.04
# ----------------------------------------
# User: 287
# Relevant Recommendations (top k): {'Spirited Away (Sen to Chihiro no kamikakushi)', 'Fargo', "Schindler's List", 'Fight Club'}
# Precision@k: 0.08
# Recall@k: 0.08333333333333333
# ----------------------------------------
# User: 39
# Relevant Recommendations (top k): {'Fargo', 'Raiders of the Lost Ark (Indiana Jones and the Raiders of the Lost Ark)', 'Pulp Fiction', 'Psycho', 'Star Wars: Episode V - The Empire Strikes Back', 'Goodfellas', 'Back to the Future', 'Terminator 2: Judgment Day', 'Aliens', 'Die Hard'}
# Precision@k: 0.2
# Recall@k: 0.14084507042253522
# ----------------------------------------
# User: 18
# Relevant Recommendations (top k): {'Eternal Sunshine of the Spotless Mind', 'Inception', 'Goodfellas', 'The Martian', 'Star Wars: Episode V - The Empire Strikes Back', '12 Angry Men', 'Gladiator', 'Saving Private Ryan', "Schindler's List", 'The Dark Knight', 'Braveheart', 'American History X', 'Fargo', "Once Upon a Time in the West (C'era una volta il West)", 'Forrest Gump', 'Pulp Fiction', 'Memento', 'Psycho', 'Interstellar', 'Fight Club', 'Life Is Beautiful (La Vita è bella)', 'Good Will Hunting'}
# Precision@k: 0.44
# Recall@k: 0.08088235294117647
# ----------------------------------------
# User: 146
# Relevant Recommendations (top k): set()
# Precision@k: 0.0
# Recall@k: 0.0
# ----------------------------------------
# User: 24
# Relevant Recommendations (top k): {'Forrest Gump', 'Pulp Fiction', 'Up', 'Inception', 'Saving Private Ryan', 'The Martian'}
# Precision@k: 0.12
# Recall@k: 0.1111111111111111
# ----------------------------------------
# User: 410
# Relevant Recommendations (top k): {"Schindler's List", 'Up'}
# Precision@k: 0.04
# Recall@k: 0.015151515151515152
# ----------------------------------------
# User: 169
# Relevant Recommendations (top k): {'Saving Private Ryan', "Schindler's List", 'Forrest Gump'}
# Precision@k: 0.06
# Recall@k: 0.013452914798206279
# ----------------------------------------
# User: 522
# Relevant Recommendations (top k): {'Captain America: The Winter Soldier', 'Guardians of the Galaxy', 'Inception', 'Django Unchained'}
# Precision@k: 0.08
# Recall@k: 0.030303030303030304
# ----------------------------------------
# User: 219
# ...
# ----------------------------------------
# User: 493
# Relevant Recommendations (top k): {'Raiders of the Lost Ark (Indiana Jones and the Raiders of the Lost Ark)', 'Braveheart', 'Star Wars: Episode V - The Empire Strikes Back', 'Star Wars: Episode IV - A New Hope', 'Saving Private Ryan', 'Terminator 2: Judgment Day'}
# Precision@k: 0.12
# Recall@k: 0.15
# ----------------------------------------
# User: 134
# Relevant Recommendations (top k): {'Pulp Fiction', 'Se7en', 'Seven'}
# Precision@k: 0.06
# Recall@k: 0.17647058823529413
# ----------------------------------------
# User: 170
# Relevant Recommendations (top k): {'Babe', 'Braveheart'}
# Precision@k: 0.04
# Recall@k: 0.10526315789473684
# ----------------------------------------
# User: 320
# Relevant Recommendations (top k): set()
# Precision@k: 0.0
# Recall@k: 0.0
# ----------------------------------------
# User: 413
# Relevant Recommendations (top k): {'Pulp Fiction', 'Goodfellas', 'Inglourious Basterds', 'Saving Private Ryan', "Schindler's List", 'Fight Club', 'American History X'}
# Precision@k: 0.14
# Recall@k: 0.14893617021276595
# ----------------------------------------
# User: 319
# Relevant Recommendations (top k): {'WALL·E', 'Inception'}
# Precision@k: 0.04
# Recall@k: 0.06666666666666667
# ----------------------------------------
# User: 228
# Relevant Recommendations (top k): set()
# Precision@k: 0.0
# Recall@k: 0.0
# ----------------------------------------
# User: 124
# Relevant Recommendations (top k): {'American Beauty', 'Forrest Gump', 'Pulp Fiction', 'Memento', 'Requiem for a Dream'}
# Precision@k: 0.1
# Recall@k: 0.13513513513513514
# ----------------------------------------
# User: 236
# Relevant Recommendations (top k): {'Alien'}
# Precision@k: 0.02
# Recall@k: 0.047619047619047616
# ----------------------------------------
# User: 55
# Relevant Recommendations (top k): set()
# Precision@k: 0.0
# Recall@k: 0.0
# ----------------------------------------
# User: 408
# Relevant Recommendations (top k): {'Batman Begins', 'Star Wars: Episode V - The Empire Strikes Back', 'Interstellar', 'Gladiator', 'Good Will Hunting'}
# Precision@k: 0.1
# Recall@k: 0.04807692307692308
# ----------------------------------------
# User: 569
# Relevant Recommendations (top k): {'Pulp Fiction'}
# Precision@k: 0.02
# Recall@k: 0.06666666666666667
# ----------------------------------------
# User: 541
# Relevant Recommendations (top k): {'Forrest Gump'}
# Precision@k: 0.02
# Recall@k: 0.027777777777777776
# ----------------------------------------
# User: 168
# Relevant Recommendations (top k): {'Forrest Gump', 'Pulp Fiction', '12 Angry Men', 'Goodfellas', 'Inglourious Basterds'}
# Precision@k: 0.1
# Recall@k: 0.05747126436781609
# ----------------------------------------
# User: 341
# Relevant Recommendations (top k): {'Up', 'Shutter Island'}
# Precision@k: 0.04
# Recall@k: 0.06451612903225806
# ----------------------------------------
# User: 422
# Relevant Recommendations (top k): {'Fight Club', 'Goodfellas'}
# Precision@k: 0.04
# Recall@k: 0.041666666666666664
# ----------------------------------------
# User: 519
# Relevant Recommendations (top k): {'Forrest Gump'}
# Precision@k: 0.02
# Recall@k: 0.047619047619047616
# ----------------------------------------
# User: 609
# Relevant Recommendations (top k): {'Pulp Fiction', 'Forrest Gump'}
# Precision@k: 0.04
# Recall@k: 0.2
# ----------------------------------------
# User: 545
# Relevant Recommendations (top k): set()
# Precision@k: 0.0
# Recall@k: 0.0
# ----------------------------------------
# User: 87
# Relevant Recommendations (top k): {'Spirited Away (Sen to Chihiro no kamikakushi)'}
# Precision@k: 0.02
# Recall@k: 0.07692307692307693
# ----------------------------------------
# User: 163
# Relevant Recommendations (top k): set()
# Precision@k: 0.0
# Recall@k: 0.0
# ----------------------------------------
# User: 192
# Relevant Recommendations (top k): {'Forrest Gump'}
# Precision@k: 0.02
# Recall@k: 0.0625
# ----------------------------------------
# User: 291
# Relevant Recommendations (top k): {'Up', 'Avengers: Age of Ultron', 'The Hobbit: The Battle of the Five Armies'}
# Precision@k: 0.06
# Recall@k: 0.1111111111111111
# ----------------------------------------
# User: 536
# Relevant Recommendations (top k): {"Schindler's List", 'Forrest Gump'}
# Precision@k: 0.04
# Recall@k: 0.1111111111111111
# ----------------------------------------
# User: 278
# Relevant Recommendations (top k): {"Schindler's List"}
# Precision@k: 0.02
# Recall@k: 0.08333333333333333
# ----------------------------------------
# User: 435
# Relevant Recommendations (top k): {'Gladiator', 'Eternal Sunshine of the Spotless Mind', 'Inception', 'Fight Club'}
# Precision@k: 0.08
# Recall@k: 0.1111111111111111
# ----------------------------------------
# User: 366
# Relevant Recommendations (top k): {'Kill Bill: Vol. 1', 'Batman Begins', 'Interstellar', 'Inception', 'Gladiator', 'Requiem for a Dream', 'Fight Club', 'Terminator 2: Judgment Day'}
# Precision@k: 0.16
# Recall@k: 0.34782608695652173
# ----------------------------------------
# User: 315
# Relevant Recommendations (top k): set()
# Precision@k: 0.0
# Recall@k: 0.0
# ----------------------------------------
# User: 60
# Relevant Recommendations (top k): {"Schindler's List"}
# Precision@k: 0.02
# Recall@k: 0.07692307692307693
# ----------------------------------------
# User: 2
# Relevant Recommendations (top k): {'Inception'}
# Precision@k: 0.02
# Recall@k: 0.05263157894736842
# ----------------------------------------
# User: 515
# Relevant Recommendations (top k): {'Forrest Gump', 'Inception', 'Saving Private Ryan', "Schindler's List", 'Fight Club'}
# Precision@k: 0.1
# Recall@k: 0.19230769230769232
# ----------------------------------------
# User: 207
# Relevant Recommendations (top k): set()
# Precision@k: 0.0
# Recall@k: 0.0
# ----------------------------------------
# User: 446
# Relevant Recommendations (top k): {'Pulp Fiction', "Schindler's List"}
# Precision@k: 0.04
# Recall@k: 0.07407407407407407
# ----------------------------------------
# User: 147
# Relevant Recommendations (top k): set()
# Precision@k: 0.0
# Recall@k: 0.0
# ----------------------------------------
# User: 505
# Relevant Recommendations (top k): {'Memento', 'Se7en', 'Fight Club'}
# Precision@k: 0.06
# Recall@k: 0.13636363636363635
# ----------------------------------------
# User: 363
# Relevant Recommendations (top k): {'Pulp Fiction'}
# Precision@k: 0.02
# Recall@k: 0.07692307692307693
# ----------------------------------------
# User: 324
# Relevant Recommendations (top k): set()
# Precision@k: 0.0
# Recall@k: 0.0
# ----------------------------------------
# User: 468
# Relevant Recommendations (top k): {'Braveheart'}
# Precision@k: 0.02
# Recall@k: 0.07142857142857142
# ----------------------------------------
# User: 67
# Relevant Recommendations (top k): {'Forrest Gump', 'Pulp Fiction', 'Inception', 'Saving Private Ryan', 'Fight Club', 'Léon: The Professional'}
# Precision@k: 0.12
# Recall@k: 0.23076923076923078
# ----------------------------------------
# User: 164
# Relevant Recommendations (top k): {'Gladiator'}
# Precision@k: 0.02
# Recall@k: 0.038461538461538464
# ----------------------------------------
# User: 549
# Relevant Recommendations (top k): {'Memento', 'Saving Private Ryan', 'Inception', 'Fight Club'}
# Precision@k: 0.08
# Recall@k: 0.3333333333333333
# ----------------------------------------
# User: 345
# Relevant Recommendations (top k): {'12 Angry Men'}
# Precision@k: 0.02
# Recall@k: 0.027777777777777776
# ----------------------------------------
# User: 133
# Relevant Recommendations (top k): {'Se7en', "Schindler's List", 'Forrest Gump'}
# Precision@k: 0.06
# Recall@k: 0.42857142857142855
# ----------------------------------------
# User: 378
# Relevant Recommendations (top k): {'Batman Begins', 'Interstellar', 'Inception', 'Goodfellas', "Schindler's List", 'American History X', 'Shutter Island'}
# Precision@k: 0.14
# Recall@k: 0.21212121212121213
# ----------------------------------------
# User: 243
# Relevant Recommendations (top k): {'Terminator 2: Judgment Day', 'Forrest Gump'}
# Precision@k: 0.04
# Recall@k: 0.07692307692307693
# ----------------------------------------
# User: 521
# Relevant Recommendations (top k): {'Fargo'}
# Precision@k: 0.02
# Recall@k: 0.045454545454545456
# ----------------------------------------
# User: 172
# Relevant Recommendations (top k): {'Gladiator', 'Kill Bill: Vol. 2', 'Back to the Future'}
# Precision@k: 0.06
# Recall@k: 0.21428571428571427
# ----------------------------------------
# User: 258
# Relevant Recommendations (top k): {'Up', 'WALL·E', 'Fight Club'}
# Precision@k: 0.06
# Recall@k: 0.15789473684210525
# ----------------------------------------
# User: 92
# Relevant Recommendations (top k): set()
# Precision@k: 0.0
# Recall@k: 0.0
# ----------------------------------------
# User: 397
# Relevant Recommendations (top k): set()
# Precision@k: 0.0
# Recall@k: 0.0
# ----------------------------------------
# User: 467
# Relevant Recommendations (top k): {'Life Is Beautiful (La Vita è bella)', 'Saving Private Ryan', "Schindler's List"}
# Precision@k: 0.06
# Recall@k: 0.23076923076923078
# ----------------------------------------
# User: 565
# Relevant Recommendations (top k): {'Pulp Fiction', "Schindler's List", 'Forrest Gump'}
# Precision@k: 0.06
# Recall@k: 0.1875
# ----------------------------------------
# User: 507
# Relevant Recommendations (top k): {'Forrest Gump'}
# Precision@k: 0.02
# Recall@k: 0.16666666666666666
# ----------------------------------------
# User: 538
# Relevant Recommendations (top k): {'Up', 'Spirited Away'}
# Precision@k: 0.04
# Recall@k: 0.058823529411764705
# ----------------------------------------
# User: 501
# Relevant Recommendations (top k): set()
# Precision@k: 0.0
# Recall@k: 0.0
# ----------------------------------------
# User: 142
# Relevant Recommendations (top k): {'Pulp Fiction', 'Se7en', "Schindler's List", 'Forrest Gump'}
# Precision@k: 0.08
# Recall@k: 0.16
# ----------------------------------------
# User: 235
# Relevant Recommendations (top k): {'Jurassic Park', 'Forrest Gump', 'Pulp Fiction', 'Braveheart', "Schindler's List", 'Terminator 2: Judgment Day'}
# Precision@k: 0.12
# Recall@k: 0.15789473684210525
# ----------------------------------------
# User: 205
# Relevant Recommendations (top k): {'Inglourious Basterds', 'Kill Bill: Vol. 1', 'Forrest Gump'}
# Precision@k: 0.06
# Recall@k: 0.16666666666666666
# ----------------------------------------
# User: 262
# Relevant Recommendations (top k): {'Fargo'}
# Precision@k: 0.02
# Recall@k: 0.07692307692307693
# ----------------------------------------
# User: 443
# Relevant Recommendations (top k): {'Brave'}
# Precision@k: 0.02
# Recall@k: 0.034482758620689655
# ----------------------------------------
# User: 196
# Relevant Recommendations (top k): {'Gladiator', 'Spotlight'}
# Precision@k: 0.04
# Recall@k: 0.10526315789473684
# ----------------------------------------
# User: 485
# Relevant Recommendations (top k): {'Forrest Gump'}
# Precision@k: 0.02
# Recall@k: 0.0625
# ----------------------------------------
# User: 175
# Relevant Recommendations (top k): set()
# Precision@k: 0.0
# Recall@k: 0.0
# ----------------------------------------
# User: 531
# Relevant Recommendations (top k): set()
# Precision@k: 0.0
# Recall@k: 0.0
# ----------------------------------------
# User: 194
# Relevant Recommendations (top k): set()
# Precision@k: 0.0
# Recall@k: 0.0
# ----------------------------------------
# User: 224
# Relevant Recommendations (top k): {'Saving Private Ryan', "Schindler's List", 'Forrest Gump'}
# Precision@k: 0.06
# Recall@k: 0.06521739130434782
# ----------------------------------------
# User: 333
# Relevant Recommendations (top k): {'Gladiator'}
# Precision@k: 0.02
# Recall@k: 0.16666666666666666
# ----------------------------------------
# User: 126
# Relevant Recommendations (top k): {'Forrest Gump'}
# Precision@k: 0.02
# Recall@k: 0.05555555555555555
# ----------------------------------------
# User: 403
# Relevant Recommendations (top k): {'Pulp Fiction', 'Braveheart', 'American History X', 'Goodfellas'}
# Precision@k: 0.08
# Recall@k: 0.23529411764705882
# ----------------------------------------
# User: 575
# Relevant Recommendations (top k): {'Pulp Fiction'}
# Precision@k: 0.02
# Recall@k: 0.07142857142857142
# ----------------------------------------
# User: 327
# Relevant Recommendations (top k): set()
# Precision@k: 0.0
# Recall@k: 0.0
# ----------------------------------------
# User: 203
# Relevant Recommendations (top k): {'Pulp Fiction', 'Braveheart', 'Gladiator'}
# Precision@k: 0.06
# Recall@k: 0.12
# ----------------------------------------
# User: 547
# Relevant Recommendations (top k): set()
# Precision@k: 0.0
# Recall@k: 0.0
# ----------------------------------------
# User: 295
# Relevant Recommendations (top k): {'Pulp Fiction', 'Memento', 'Inception', 'Goodfellas', 'Fight Club', 'American History X', 'City of God (Cidade de Deus)'}
# Precision@k: 0.14
# Recall@k: 0.2692307692307692
# ----------------------------------------
# User: 449
# Relevant Recommendations (top k): {'Memento', "Schindler's List", 'Léon: The Professional (a.k.a. The Professional) (Léon)', 'Fight Club', 'American History X'}
# Precision@k: 0.1
# Recall@k: 0.3125
# ----------------------------------------
# User: 399
# Relevant Recommendations (top k): {'Raiders of the Lost Ark (Indiana Jones and the Raiders of the Lost Ark)', 'Forrest Gump', 'Pulp Fiction', 'Star Wars: Episode V - The Empire Strikes Back', 'Star Wars: Episode IV - A New Hope', 'Back to the Future', 'Gladiator', "Schindler's List"}
# Precision@k: 0.16
# Recall@k: 0.3333333333333333
# ----------------------------------------
# User: 118
# Relevant Recommendations (top k): {'Fargo', 'Pulp Fiction', 'Goodfellas', 'Saving Private Ryan', "Schindler's List"}
# Precision@k: 0.1
# Recall@k: 0.3125
# ----------------------------------------
# User: 293
# Relevant Recommendations (top k): set()
# Precision@k: 0.0
# Recall@k: 0.0
# ----------------------------------------
# User: 388
# Relevant Recommendations (top k): set()
# Precision@k: 0.0
# Recall@k: 0.0
# ----------------------------------------
# User: 394
# Relevant Recommendations (top k): {'Braveheart', 'Usual Suspects, The', 'Forrest Gump'}
# Precision@k: 0.06
# Recall@k: 0.5
# ----------------------------------------
# User: 250
# Relevant Recommendations (top k): set()
# Precision@k: 0.0
# Recall@k: 0.0
# ----------------------------------------
# User: 530
# Relevant Recommendations (top k): {'Forrest Gump'}
# Precision@k: 0.02
# Recall@k: 0.058823529411764705
# ----------------------------------------
# User: 407
# Relevant Recommendations (top k): {'Saving Private Ryan', 'Fight Club'}
# Precision@k: 0.04
# Recall@k: 0.13333333333333333
# ----------------------------------------
# User: 461
# Relevant Recommendations (top k): {'Shutter Island', 'Goodfellas'}
# Precision@k: 0.04
# Recall@k: 0.125
# ----------------------------------------
# User: 5
# Relevant Recommendations (top k): {'Pulp Fiction', 'Braveheart', "Schindler's List"}
# Precision@k: 0.06
# Recall@k: 0.13043478260869565
# ----------------------------------------
# User: 550
# Relevant Recommendations (top k): {'Up', 'Inception', 'WALL·E'}
# Precision@k: 0.06
# Recall@k: 0.12
# ----------------------------------------
# User: 349
# Relevant Recommendations (top k): {'Pulp Fiction', "Schindler's List", 'Terminator 2: Judgment Day', 'Forrest Gump'}
# Precision@k: 0.08
# Recall@k: 0.19047619047619047
# ----------------------------------------
# User: 311
# Relevant Recommendations (top k): set()
# Precision@k: 0.0
# Recall@k: 0.0
# ----------------------------------------
# User: 578
# Relevant Recommendations (top k): set()
# Precision@k: 0.0
# Recall@k: 0.0
# ----------------------------------------
# User: 158
# Relevant Recommendations (top k): set()
# Precision@k: 0.0
# Recall@k: 0.0
# ----------------------------------------
# User: 257
# Relevant Recommendations (top k): set()
# Precision@k: 0.0
# Recall@k: 0.0
# ----------------------------------------
# User: 496
# Relevant Recommendations (top k): set()
# Precision@k: 0.0
# Recall@k: 0.0
# ----------------------------------------
# User: 392
# Relevant Recommendations (top k): set()
# Precision@k: 0.0
# Recall@k: 0.0
# ----------------------------------------
# User: 138
# Relevant Recommendations (top k): set()
# Precision@k: 0.0
# Recall@k: 0.0
# ----------------------------------------
# User: 375
# Relevant Recommendations (top k): {'Memento', 'Forrest Gump'}
# Precision@k: 0.04
# Recall@k: 0.09523809523809523
# ----------------------------------------
# Average Precision@50 across all users: 0.09124590163934454
# Average Recall@50 across all users: 0.08459083536984179
