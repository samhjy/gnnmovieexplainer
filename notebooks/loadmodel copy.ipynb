# %%
import random
from tqdm import tqdm
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

import torch
from torch import nn, optim, Tensor

from torch_sparse import SparseTensor, matmul

from torch_geometric.utils import structured_negative_sampling
from torch_geometric.data import Data, Dataset, download_url, extract_zip
from torch_geometric.nn.conv.gcn_conv import gcn_norm
from torch_geometric.nn.conv import MessagePassing
from torch_geometric.typing import Adj
# Out:
# /var/folders/rh/6zv88sms5vddqjk7_7d0f5v00000gn/T/ipykernel_64213/2170324891.py:3: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
# defines LightGCN model
class LightGCN(MessagePassing):
    """LightGCN Model as proposed in https://arxiv.org/abs/2002.02126
    """

    def __init__(self, num_users, num_items, embedding_dim=64, K=3, add_self_loops=False):
        """Initializes LightGCN Model

        Args:
            num_users (int): Number of users
            num_items (int): Number of items
            embedding_dim (int, optional): Dimensionality of embeddings. Defaults to 8.
            K (int, optional): Number of message passing layers. Defaults to 3.
            add_self_loops (bool, optional): Whether to add self loops for message passing. Defaults to False.
        """
        super().__init__()
        self.num_users, self.num_items = num_users, num_items
        self.embedding_dim, self.K = embedding_dim, K
        self.add_self_loops = add_self_loops

        self.users_emb = nn.Embedding(
            num_embeddings=self.num_users, embedding_dim=self.embedding_dim) # e_u^0
        self.items_emb = nn.Embedding(
            num_embeddings=self.num_items, embedding_dim=self.embedding_dim) # e_i^0

        nn.init.normal_(self.users_emb.weight, std=0.1)
        nn.init.normal_(self.items_emb.weight, std=0.1)

    def forward(self, edge_index: SparseTensor):
        """Forward propagation of LightGCN Model.

        Args:
            edge_index (SparseTensor): adjacency matrix

        Returns:
            tuple (Tensor): e_u_k, e_u_0, e_i_k, e_i_0
        """
        # compute \tilde{A}: symmetrically normalized adjacency matrix
        edge_index_norm = gcn_norm(
            edge_index, add_self_loops=self.add_self_loops)

        emb_0 = torch.cat([self.users_emb.weight, self.items_emb.weight]) # E^0
        embs = [emb_0]
        emb_k = emb_0

        # multi-scale diffusion
        for i in range(self.K):
            emb_k = self.propagate(edge_index_norm, x=emb_k)
            embs.append(emb_k)

        embs = torch.stack(embs, dim=1)
        emb_final = torch.mean(embs, dim=1) # E^K

        users_emb_final, items_emb_final = torch.split(
            emb_final, [self.num_users, self.num_items]) # splits into e_u^K and e_i^K

        # returns e_u^K, e_u^0, e_i^K, e_i^0
        return users_emb_final, self.users_emb.weight, items_emb_final, self.items_emb.weight

    def message(self, x_j: Tensor) -> Tensor:
        return x_j

    def message_and_aggregate(self, adj_t: SparseTensor, x: Tensor) -> Tensor:
        # computes \tilde{A} @ x
        return matmul(adj_t, x)

# %%
def load_node_csv(path, index_col):
    """Loads csv containing node information

    Args:
        path (str): path to csv file
        index_col (str): column name of index column

    Returns:
        dict: mapping of csv row to node id
    """
    df = pd.read_csv(path, index_col=index_col)
    mapping = {index: i for i, index in enumerate(df.index.unique())}
    return mapping


movie_path = '/Users/samanthatan/Desktop/ml-latest-small/movies.csv'
rating_path = '/Users/samanthatan/Desktop/ml-latest-small/ratings.csv'

user_mapping = load_node_csv(rating_path, index_col='userId')
movie_mapping = load_node_csv(movie_path, index_col='movieId')

# %%
def load_edge_csv(path, src_index_col, src_mapping, dst_index_col, dst_mapping, link_index_col, rating_threshold=4):
    """Loads csv containing edges between users and items

    Args:
        path (str): path to csv file
        src_index_col (str): column name of users
        src_mapping (dict): mapping between row number and user id
        dst_index_col (str): column name of items
        dst_mapping (dict): mapping between row number and item id
        link_index_col (str): column name of user item interaction
        rating_threshold (int, optional): Threshold to determine positivity of edge. Defaults to 4.

    Returns:
        torch.Tensor: 2 by N matrix containing the node ids of N user-item edges
    """
    df = pd.read_csv(path)
    edge_index = None
    src = [src_mapping[index] for index in df[src_index_col]]
    dst = [dst_mapping[index] for index in df[dst_index_col]]
    edge_attr = torch.from_numpy(df[link_index_col].values).view(-1, 1).to(torch.long) >= rating_threshold


    edge_index = [[], []]
    for i in range(edge_attr.shape[0]):
        if edge_attr[i]:
            edge_index[0].append(src[i])
            edge_index[1].append(dst[i])

    return torch.tensor(edge_index)

# %%
# helper function to get N_u
def get_user_positive_items(edge_index):
    """Generates dictionary of positive items for each user

    Args:
        edge_index (torch.Tensor): 2 by N list of edges

    Returns:
        dict: dictionary of positive items for each user
    """
    user_pos_items = {}
    for i in range(edge_index.shape[1]):
        user = edge_index[0][i].item()
        item = edge_index[1][i].item()
        if user not in user_pos_items:
            user_pos_items[user] = []
        user_pos_items[user].append(item)
    return user_pos_items

# %%
edge_index = load_edge_csv(
    rating_path,
    src_index_col='userId',
    src_mapping=user_mapping,
    dst_index_col='movieId',
    dst_mapping=movie_mapping,
    link_index_col='rating',
    rating_threshold=4,
)

# %%
# Load the trained LightGCN model
PATH2 = "lightgcn2.pt"
model = torch.load(PATH2)
model.eval()  # Set model to evaluation mode
# Out:
# LightGCN()

# %%
def make_predictions(user_id, num_recs):
    user = user_mapping[user_id]
    e_u = model.users_emb.weight[user]
    scores = model.items_emb.weight @ e_u

    values, indices = torch.topk(scores, k=len(user_pos_items[user]) + num_recs)

    movies = [index.cpu().item() for index in indices if index in user_pos_items[user]][:10]
    movie_ids = [list(movie_mapping.keys())[list(movie_mapping.values()).index(movie)] for movie in movies]
    titles = [movieid_title[id] for id in movie_ids]
    genres = [movieid_genres[id] for id in movie_ids]

    # print(f"Here are some movies that user {user_id} rated highly")
    # for i in range(10):
    #     print(f"title: {titles[i]}, genres: {genres[i]} ")

    # print()

    movies = [index.cpu().item() for index in indices if index not in user_pos_items[user]][:num_recs]
    movie_ids = [list(movie_mapping.keys())[list(movie_mapping.values()).index(movie)] for movie in movies]
    titles = [movieid_title[id] for id in movie_ids]
    genres = [movieid_genres[id] for id in movie_ids]
    return titles

    # print(f"Here are some suggested movies for user {user_id}")
    # for i in range(num_recs):
        # print(f"title: {titles[i]}, genres: {genres[i]} ")

# %%
model.eval()
df = pd.read_csv(movie_path)
movieid_title = pd.Series(df.title.values,index=df.movieId).to_dict()
movieid_genres = pd.Series(df.genres.values,index=df.movieId).to_dict()

user_pos_items = get_user_positive_items(edge_index)

# %%
USER_ID = 1
NUM_RECS = 50

make_predictions(USER_ID, NUM_RECS)
# Out:
# ['Shawshank Redemption, The (1994)',
#  'Pulp Fiction (1994)',
#  'Godfather, The (1972)',
#  'Terminator 2: Judgment Day (1991)',
#  'Lord of the Rings: The Fellowship of the Ring, The (2001)',
#  'Apollo 13 (1995)',
#  'Lord of the Rings: The Two Towers, The (2002)',
#  'Lord of the Rings: The Return of the King, The (2003)',
#  'Eternal Sunshine of the Spotless Mind (2004)',
#  'Sixth Sense, The (1999)',
#  'Aladdin (1992)',
#  'Twelve Monkeys (a.k.a. 12 Monkeys) (1995)',
#  'Godfather: Part II, The (1974)',
#  'Memento (2000)',
#  "One Flew Over the Cuckoo's Nest (1975)",
#  'Dark Knight, The (2008)',
#  'Shrek (2001)',
#  'Finding Nemo (2003)',
#  'Good Will Hunting (1997)',
#  'Lion King, The (1994)',
#  'Inception (2010)',
#  'Kill Bill: Vol. 1 (2003)',
#  'Die Hard (1988)',
#  'Independence Day (a.k.a. ID4) (1996)',
#  'Pirates of the Caribbean: The Curse of the Black Pearl (2003)',
#  'Speed (1994)',
#  'Departed, The (2006)',
#  'Monsters, Inc. (2001)',
#  'Casablanca (1942)',
#  'Beautiful Mind, A (2001)',
#  'Beauty and the Beast (1991)',
#  'Aliens (1986)',
#  'Blade Runner (1982)',
#  'Incredibles, The (2004)',
#  'Bourne Identity, The (2002)',
#  'Léon: The Professional (a.k.a. The Professional) (Léon) (1994)',
#  'Truman Show, The (1998)',
#  "Amelie (Fabuleux destin d'Amélie Poulain, Le) (2001)",
#  'Donnie Darko (2001)',
#  'Batman Begins (2005)',
#  'Mission: Impossible (1996)',
#  'Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb (1964)',
#  'Trainspotting (1996)',
#  'Taxi Driver (1976)',
#  'Die Hard: With a Vengeance (1995)',
#  'Four Weddings and a Funeral (1994)',
#  'Spirited Away (Sen to Chihiro no kamikakushi) (2001)',
#  'Snatch (2000)',
#  'Breakfast Club, The (1985)',
#  'Fifth Element, The (1997)']

# %%
import google.generativeai as genai
import os
import json

GEMINI_API_KEY = "AIzaSyBhFKb9IwvzAZDUwzy-_iUBwOIfHrppeMo"

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import precision_score, recall_score
import re

# %%
# Load the datasets
movies_df = pd.read_csv('/Users/samanthatan/Desktop/ml-latest-small/movies.csv')
ratings_df = pd.read_csv('/Users/samanthatan/Desktop/ml-latest-small/ratings.csv')

merged_df = pd.merge(ratings_df, movies_df, on='movieId', how='inner')

# %%
train_df, test_df = train_test_split(merged_df, test_size=0.2, random_state=42)

# %%
# Get unique test users
test_users = test_df['userId'].unique()
len(test_users)
# Out:
# 610

# %%
# Creating a dictionary of user histories
user_histories = {}

# Iterate over each row in the merged DataFrame
for _, row in train_df.iterrows():
    user_id = row['userId']
    movie_info = {
        'movieId': row['movieId'],
        'title': row['title'],
        'rating': row['rating'],
        'genres': row['genres']
    }
    
    # Initialize list if user_id is not yet in dictionary
    if user_id not in user_histories:
        user_histories[user_id] = []
    
    # Append the movie info to the user's history
    user_histories[user_id].append(movie_info)

# Display the user histories
len(user_histories)
# Out:
# 610

# %%
for user in test_users[108:]:
    ratings = user_histories.get(user)
    prompt = f"Based on the user's previous movie ratings: {ratings}, a LightGCN model has recommended the following movies: {make_predictions(user, 50)}. The model is performing with a precision and recall of 10%. Remove movies that you think does not fit the user, and recommend new movies from the popular MovieLens Latest dataset from https://files.grouplens.org/datasets/movielens/ml-latest-small.zip for the user to watch."
    prompt += """Respond with only the titles in json format: OUTPUT = {
"recommendation": [/* array of movies */]
}"""
    recommendation = get_gemini_recommendations(prompt)
    titles_list = recommendation.split("{")[1]
    recommendations_list = eval(re.search(r'\[.*?\]', titles_list, re.DOTALL).group(0))
    recommendations_without_years = [re.sub(r"\s\(\d{4}\)$", "", title) for title in recommendations_list]
    all_recommendations[user] = recommendations_without_years
# Out:
# ---------------------------------------------------------------------------
# ResourceExhausted                         Traceback (most recent call last)
# Cell In[51], line 7
#       3     prompt = f"Based on the user's previous movie ratings: {ratings}, a LightGCN model has recommended the following movies: {make_predictions(user, 50)}. The model is performing with a precision and recall of 10%. Remove movies that you think does not fit the user, and recommend new movies from the popular MovieLens Latest dataset from https://files.grouplens.org/datasets/movielens/ml-latest-small.zip for the user to watch."
#       4     prompt += """Respond with only the titles in json format: OUTPUT = {
#       5 "recommendation": [/* array of movies */]
#       6 }"""
# ----> 7     recommendation = get_gemini_recommendations(prompt)
#       8     titles_list = recommendation.split("{")[1]
#       9     recommendations_list = eval(re.search(r'\[.*?\]', titles_list, re.DOTALL).group(0))
#
# Cell In[17], line 5, in get_gemini_recommendations(prompt)
#       3 def get_gemini_recommendations(prompt):
#       4     model = genai.GenerativeModel("gemini-1.5-flash")
# ----> 5     response = model.generate_content(prompt)
#       6     # print(response.text)
#       7     return (response.text)
#
# File /usr/local/lib/python3.9/site-packages/google/generativeai/generative_models.py:331, in GenerativeModel.generate_content(self, contents, generation_config, safety_settings, stream, tools, tool_config, request_options)
#     329         return generation_types.GenerateContentResponse.from_iterator(iterator)
#     330     else:
# --> 331         response = self._client.generate_content(
#     332             request,
#     333             **request_options,
#     334         )
#     335         return generation_types.GenerateContentResponse.from_response(response)
#     336 except google.api_core.exceptions.InvalidArgument as e:
#
# File /usr/local/lib/python3.9/site-packages/google/ai/generativelanguage_v1beta/services/generative_service/client.py:830, in GenerativeServiceClient.generate_content(self, request, model, contents, retry, timeout, metadata)
#     827 self._validate_universe_domain()
#     829 # Send the request.
# --> 830 response = rpc(
#     831     request,
#     832     retry=retry,
#     833     timeout=timeout,
#     834     metadata=metadata,
#     835 )
#     837 # Done; return the response.
#     838 return response
#
# File /usr/local/lib/python3.9/site-packages/google/api_core/gapic_v1/method.py:131, in _GapicCallable.__call__(self, timeout, retry, compression, *args, **kwargs)
#     128 if self._compression is not None:
#     129     kwargs["compression"] = compression
# --> 131 return wrapped_func(*args, **kwargs)
#
# File /usr/local/lib/python3.9/site-packages/google/api_core/retry/retry_unary.py:293, in Retry.__call__.<locals>.retry_wrapped_func(*args, **kwargs)
#     289 target = functools.partial(func, *args, **kwargs)
#     290 sleep_generator = exponential_sleep_generator(
#     291     self._initial, self._maximum, multiplier=self._multiplier
#     292 )
# --> 293 return retry_target(
#     294     target,
#     295     self._predicate,
#     296     sleep_generator,
#     297     timeout=self._timeout,
#     298     on_error=on_error,
#     299 )
#
# File /usr/local/lib/python3.9/site-packages/google/api_core/retry/retry_unary.py:153, in retry_target(target, predicate, sleep_generator, timeout, on_error, exception_factory, **kwargs)
#     149 # pylint: disable=broad-except
#     150 # This function explicitly must deal with broad exceptions.
#     151 except Exception as exc:
#     152     # defer to shared logic for handling errors
# --> 153     _retry_error_helper(
#     154         exc,
#     155         deadline,
#     156         sleep,
#     157         error_list,
#     158         predicate,
#     159         on_error,
#     160         exception_factory,
#     161         timeout,
#     162     )
#     163     # if exception not raised, sleep before next attempt
#     164     time.sleep(sleep)
#
# File /usr/local/lib/python3.9/site-packages/google/api_core/retry/retry_base.py:212, in _retry_error_helper(exc, deadline, next_sleep, error_list, predicate_fn, on_error_fn, exc_factory_fn, original_timeout)
#     206 if not predicate_fn(exc):
#     207     final_exc, source_exc = exc_factory_fn(
#     208         error_list,
#     209         RetryFailureReason.NON_RETRYABLE_ERROR,
#     210         original_timeout,
#     211     )
# --> 212     raise final_exc from source_exc
#     213 if on_error_fn is not None:
#     214     on_error_fn(exc)
#
# File /usr/local/lib/python3.9/site-packages/google/api_core/retry/retry_unary.py:144, in retry_target(target, predicate, sleep_generator, timeout, on_error, exception_factory, **kwargs)
#     142 for sleep in sleep_generator:
#     143     try:
# --> 144         result = target()
#     145         if inspect.isawaitable(result):
#     146             warnings.warn(_ASYNC_RETRY_WARNING)
#
# File /usr/local/lib/python3.9/site-packages/google/api_core/timeout.py:120, in TimeToDeadlineTimeout.__call__.<locals>.func_with_timeout(*args, **kwargs)
#     117     # Avoid setting negative timeout
#     118     kwargs["timeout"] = max(0, self._timeout - time_since_first_attempt)
# --> 120 return func(*args, **kwargs)
#
# File /usr/local/lib/python3.9/site-packages/google/api_core/grpc_helpers.py:78, in _wrap_unary_errors.<locals>.error_remapped_callable(*args, **kwargs)
#      76     return callable_(*args, **kwargs)
#      77 except grpc.RpcError as exc:
# ---> 78     raise exceptions.from_grpc_error(exc) from exc
#
# ResourceExhausted: 429 Resource has been exhausted (e.g. check quota).

# %%
len(all_recommendations)
# Out:
# 117

# %%
def get_high_rated_movies_by_user(movies_df, ratings_df):
    # Merge movies and ratings data to include movie titles
    merged_df = pd.merge(ratings_df, movies_df, on='movieId', how='inner')
    
    # Filter for ratings >= 4
    high_rated_df = merged_df[merged_df['rating'] >= 4]
    
    # Group by userId and collect titles in a list for each user
    user_high_rated_movies = high_rated_df.groupby('userId')['title'].apply(list).to_dict()
    
    return user_high_rated_movies

# Usage
user_high_rated_movies = get_high_rated_movies_by_user(movies_df, ratings_df)

# %%
# Initialize counters for cumulative precision@k and recall@k
total_precision_at_k = 0
total_recall_at_k = 0
user_count = len(test_users)

# Set the value of k
k = 50  # You can adjust this to any desired value of k

# Iterate through each user to calculate precision@k and recall@k
for user in test_users:
    test = user_high_rated_movies.get(user, [])
    titles = all_recommendations.get(user, [])[:k]  # Take only the top k recommendations

    relevant_recommended = set()
    for recommended_movie in titles:
        for liked_movie in test:
            if recommended_movie in liked_movie or liked_movie in recommended_movie:
                relevant_recommended.add(recommended_movie)
                break  # Break to avoid duplicate addition

    # Calculate precision@k and recall@k for the current user
    precision_at_k = len(relevant_recommended) / k if titles else 0
    recall_at_k = len(relevant_recommended) / len(test) if test else 0

    # Accumulate precision@k and recall@k
    total_precision_at_k += precision_at_k
    total_recall_at_k += recall_at_k

    print(f"User: {user}")
    print("Relevant Recommendations (top k):", relevant_recommended)
    print("Precision@k:", precision_at_k)
    print("Recall@k:", recall_at_k)
    print("-" * 40)

# Calculate average precision@k and recall@k across all users
average_precision_at_k = total_precision_at_k / user_count if user_count else 0
average_recall_at_k = total_recall_at_k / user_count if user_count else 0

print(f"Average Precision@{k} across all users:", average_precision_at_k)
print(f"Average Recall@{k} across all users:", average_recall_at_k)
# Out:
# User: 432
# Relevant Recommendations (top k): {'Toy Story'}
# Precision@k: 0.02
# Recall@k: 0.006993006993006993
# ----------------------------------------
# User: 288
# Relevant Recommendations (top k): {'Forrest Gump', 'Pulp Fiction'}
# Precision@k: 0.04
# Recall@k: 0.007246376811594203
# ----------------------------------------
# User: 599
# Relevant Recommendations (top k): {'Pulp Fiction', 'Fight Club'}
# Precision@k: 0.04
# Recall@k: 0.010526315789473684
# ----------------------------------------
# User: 42
# Relevant Recommendations (top k): {'Goodfellas', 'Forrest Gump', 'Pulp Fiction'}
# Precision@k: 0.06
# Recall@k: 0.011583011583011582
# ----------------------------------------
# User: 75
# Relevant Recommendations (top k): set()
# Precision@k: 0.0
# Recall@k: 0.0
# ----------------------------------------
# User: 51
# Relevant Recommendations (top k): set()
# Precision@k: 0.0
# Recall@k: 0.0
# ----------------------------------------
# User: 354
# Relevant Recommendations (top k): {'Forrest Gump', 'Pulp Fiction', 'Fight Club'}
# Precision@k: 0.06
# Recall@k: 0.024
# ----------------------------------------
# User: 416
# Relevant Recommendations (top k): {'Pulp Fiction', 'Fight Club'}
# Precision@k: 0.04
# Recall@k: 0.08695652173913043
# ----------------------------------------
# User: 438
# Relevant Recommendations (top k): {'Forrest Gump', 'Seven'}
# Precision@k: 0.04
# Recall@k: 0.009174311926605505
# ----------------------------------------
# User: 73
# Relevant Recommendations (top k): set()
# Precision@k: 0.0
# Recall@k: 0.0
# ----------------------------------------
# User: 567
# Relevant Recommendations (top k): set()
# Precision@k: 0.0
# Recall@k: 0.0
# ----------------------------------------
# User: 391
# Relevant Recommendations (top k): {'Forrest Gump', 'Fight Club', 'Pulp Fiction', "Schindler's List", 'Goodfellas', 'Memento'}
# Precision@k: 0.12
# Recall@k: 0.024691358024691357
# ----------------------------------------
# User: 380
# Relevant Recommendations (top k): {'Kill Bill: Vol. 1', 'Forrest Gump', 'Pulp Fiction', 'Inception', 'The Dark Knight', 'Mad Max: Fury Road', 'Fight Club'}
# Precision@k: 0.14
# Recall@k: 0.01046337817638266
# ----------------------------------------
# User: 305
# Relevant Recommendations (top k): {'Forrest Gump', 'Seven (a.k.a. Se7en)', 'American History X', 'Saving Private Ryan', 'Pulp Fiction', 'Inception', '12 Angry Men', 'Goodfellas', "Schindler's List", 'Fight Club', 'Spirited Away', 'Avengers: Infinity War - Part I', 'Lord of the Rings: The Two Towers, The', 'Lord of the Rings: The Fellowship of the Ring, The'}
# Precision@k: 0.28
# Recall@k: 0.03349282296650718
# ----------------------------------------
# User: 409
# Relevant Recommendations (top k): {'Pulp Fiction'}
# Precision@k: 0.02
# Recall@k: 0.011904761904761904
# ----------------------------------------
# User: 307
# Relevant Recommendations (top k): {'Spirited Away', 'WALL·E', 'Pulp Fiction', 'Fight Club'}
# Precision@k: 0.08
# Recall@k: 0.0213903743315508
# ----------------------------------------
# User: 274
# Relevant Recommendations (top k): {'Forrest Gump', 'Star Wars: Episode V - The Empire Strikes Back', 'Pulp Fiction', 'Inception', 'Fight Club'}
# Precision@k: 0.1
# Recall@k: 0.015772870662460567
# ----------------------------------------
# User: 125
# Relevant Recommendations (top k): {'Kill Bill: Vol. 1', 'Forrest Gump', 'Memento', 'Pulp Fiction', 'Django Unchained', 'Inception', 'The Dark Knight', 'Braveheart', 'Fight Club', 'Kill Bill: Vol. 2'}
# Precision@k: 0.2
# Recall@k: 0.042735042735042736
# ----------------------------------------
# User: 561
# Relevant Recommendations (top k): {'Pulp Fiction', 'Se7en', 'Goodfellas', 'Fight Club', 'Donnie Darko'}
# Precision@k: 0.1
# Recall@k: 0.027472527472527472
# ----------------------------------------
# User: 68
# Relevant Recommendations (top k): {'Inglourious Basterds', 'Gladiator', 'Inception', "Schindler's List", 'The Martian', 'Star Wars: Episode VII - The Force Awakens'}
# Precision@k: 0.12
# Recall@k: 0.017094017094017096
# ----------------------------------------
# User: 525
# Relevant Recommendations (top k): {'Forrest Gump', 'Inside Out', 'Inception', 'Finding Nemo', 'Mad Max: Fury Road', 'The Martian', 'Spirited Away'}
# Precision@k: 0.14
# Recall@k: 0.03317535545023697
# ----------------------------------------
# User: 414
# Relevant Recommendations (top k): {'Spirited Away (Sen to Chihiro no kamikakushi)', 'American History X', 'Django Unchained', 'The Martian', 'The Big Sick', 'Spotlight', 'Manchester by the Sea', 'Whiplash', 'Forrest Gump', 'Interstellar', 'City of God (Cidade de Deus)', 'Inglourious Basterds', 'Saving Private Ryan', 'Arrival', 'Moonlight', "One Flew Over the Cuckoo's Nest", 'Inception', 'Braveheart', 'Lady Bird', 'Memento', 'The Shape of Water', 'Pulp Fiction', 'Goodfellas', 'The Hateful Eight', 'Fight Club', 'Fargo', 'Seven (a.k.a. Se7en)', 'Casablanca', 'Gone Girl', 'The Artist', "Schindler's List"}
# Precision@k: 0.62
# Recall@k: 0.02526487367563162
# ----------------------------------------
# User: 6
# Relevant Recommendations (top k): {'Forrest Gump'}
# Precision@k: 0.02
# Recall@k: 0.007042253521126761
# ----------------------------------------
# User: 601
# Relevant Recommendations (top k): {'Spirited Away', 'Inception', 'Memento', 'Fight Club'}
# Precision@k: 0.08
# Recall@k: 0.041237113402061855
# ----------------------------------------
# User: 325
# Relevant Recommendations (top k): {'Pulp Fiction'}
# Precision@k: 0.02
# Recall@k: 0.006369426751592357
# ----------------------------------------
# User: 82
# Relevant Recommendations (top k): {'Gladiator'}
# Precision@k: 0.02
# Recall@k: 0.0125
# ----------------------------------------
# User: 16
# Relevant Recommendations (top k): {'Spirited Away', '12 Angry Men', "Schindler's List"}
# Precision@k: 0.06
# Recall@k: 0.05660377358490566
# ----------------------------------------
# User: 542
# Relevant Recommendations (top k): {'Forrest Gump', 'Fight Club'}
# Precision@k: 0.04
# Recall@k: 0.03125
# ----------------------------------------
# User: 32
# Relevant Recommendations (top k): {'Casablanca', "Schindler's List", 'Pulp Fiction'}
# Precision@k: 0.06
# Recall@k: 0.05
# ----------------------------------------
# User: 140
# Relevant Recommendations (top k): {"Schindler's List", 'Forrest Gump', 'Pulp Fiction'}
# Precision@k: 0.06
# Recall@k: 0.010526315789473684
# ----------------------------------------
# User: 182
# Relevant Recommendations (top k): {'Seven (a.k.a. Se7en)', 'Forrest Gump', 'American History X', 'Pulp Fiction', "Schindler's List", 'Goodfellas', 'Fight Club'}
# Precision@k: 0.14
# Recall@k: 0.014344262295081968
# ----------------------------------------
# User: 89
# Relevant Recommendations (top k): set()
# Precision@k: 0.0
# Recall@k: 0.0
# ----------------------------------------
# User: 359
# Relevant Recommendations (top k): set()
# Precision@k: 0.0
# Recall@k: 0.0
# ----------------------------------------
# User: 183
# Relevant Recommendations (top k): {'Die Hard'}
# Precision@k: 0.02
# Recall@k: 0.02564102564102564
# ----------------------------------------
# User: 111
# Relevant Recommendations (top k): {'Inception', 'Forrest Gump', 'Fight Club'}
# Precision@k: 0.06
# Recall@k: 0.011764705882352941
# ----------------------------------------
# User: 80
# Relevant Recommendations (top k): {'Inception', 'Memento', 'Fight Club'}
# Precision@k: 0.06
# Recall@k: 0.019736842105263157
# ----------------------------------------
# User: 448
# Relevant Recommendations (top k): {'Jurassic Park'}
# Precision@k: 0.02
# Recall@k: 0.002197802197802198
# ----------------------------------------
# User: 514
# Relevant Recommendations (top k): {'Whiplash', 'Interstellar', 'Inception', 'Shutter Island', 'Spotlight'}
# Precision@k: 0.1
# Recall@k: 0.026455026455026454
# ----------------------------------------
# User: 509
# Relevant Recommendations (top k): {'Toy Story 3', 'Spirited Away (Sen to Chihiro no kamikakushi)', "Howl's Moving Castle (Hauru no ugoku shiro)"}
# Precision@k: 0.06
# Recall@k: 0.03488372093023256
# ----------------------------------------
# User: 131
# Relevant Recommendations (top k): {'Seven (a.k.a. Se7en)', 'Léon: The Professional (a.k.a. The Professional) (Léon)', 'Pulp Fiction', 'Inception', 'Goodfellas', 'Memento'}
# Precision@k: 0.12
# Recall@k: 0.20689655172413793
# ----------------------------------------
# User: 45
# Relevant Recommendations (top k): {'American Beauty', 'Pulp Fiction', 'Office Space', 'Fight Club', 'Being John Malkovich'}
# Precision@k: 0.1
# Recall@k: 0.018518518518518517
# ----------------------------------------
# User: 156
# Relevant Recommendations (top k): {'Goodfellas', 'Pulp Fiction'}
# Precision@k: 0.04
# Recall@k: 0.009259259259259259
# ----------------------------------------
# User: 440
# Relevant Recommendations (top k): {'Eternal Sunshine of the Spotless Mind'}
# Precision@k: 0.02
# Recall@k: 0.047619047619047616
# ----------------------------------------
# User: 312
# Relevant Recommendations (top k): {'Back to the Future'}
# Precision@k: 0.02
# Recall@k: 0.007142857142857143
# ----------------------------------------
# User: 57
# Relevant Recommendations (top k): {'Monty Python and the Holy Grail'}
# Precision@k: 0.02
# Recall@k: 0.0041841004184100415
# ----------------------------------------
# User: 603
# Relevant Recommendations (top k): {'Casablanca', 'American Beauty', 'Pulp Fiction', 'Goodfellas', 'Fight Club', 'Being John Malkovich', 'Fargo'}
# Precision@k: 0.14
# Recall@k: 0.012433392539964476
# ----------------------------------------
# User: 337
# Relevant Recommendations (top k): set()
# Precision@k: 0.0
# Recall@k: 0.0
# ----------------------------------------
# User: 116
# Relevant Recommendations (top k): {'Shrek', 'Forrest Gump'}
# Precision@k: 0.04
# Recall@k: 0.05128205128205128
# ----------------------------------------
# User: 122
# Relevant Recommendations (top k): {'Forrest Gump', 'Interstellar', 'Pulp Fiction', 'Inception', 'Goodfellas', 'Fight Club'}
# Precision@k: 0.12
# Recall@k: 0.02181818181818182
# ----------------------------------------
# User: 201
# Relevant Recommendations (top k): set()
# Precision@k: 0.0
# Recall@k: 0.0
# ----------------------------------------
# User: 167
# Relevant Recommendations (top k): set()
# Precision@k: 0.0
# Recall@k: 0.0
# ----------------------------------------
# User: 139
# Relevant Recommendations (top k): set()
# Precision@k: 0.0
# Recall@k: 0.0
# ----------------------------------------
# User: 450
# Relevant Recommendations (top k): {'Jurassic Park'}
# Precision@k: 0.02
# Recall@k: 0.023255813953488372
# ----------------------------------------
# User: 178
# Relevant Recommendations (top k): {'Forrest Gump', 'American Beauty', 'Pulp Fiction', "Schindler's List", 'Goodfellas', 'Fight Club'}
# Precision@k: 0.12
# Recall@k: 0.1
# ----------------------------------------
# User: 581
# Relevant Recommendations (top k): {'Inception', "Schindler's List", 'Forrest Gump', 'Fight Club'}
# Precision@k: 0.08
# Recall@k: 0.11428571428571428
# ----------------------------------------
# User: 215
# Relevant Recommendations (top k): {'Fight Club'}
# Precision@k: 0.02
# Recall@k: 0.015384615384615385
# ----------------------------------------
# User: 610
# Relevant Recommendations (top k): {'Kill Bill: Vol. 1', 'Seven (a.k.a. Se7en)', 'Léon: The Professional (a.k.a. The Professional) (Léon)', 'Fight Club', 'Inglourious Basterds', 'Pulp Fiction', 'Django Unchained', 'Inception', 'Goodfellas', 'Memento', 'Spirited Away', 'Kill Bill: Vol. 2'}
# Precision@k: 0.24
# Recall@k: 0.019543973941368076
# ----------------------------------------
# User: 81
# Relevant Recommendations (top k): set()
# Precision@k: 0.0
# Recall@k: 0.0
# ----------------------------------------
# User: 340
# Relevant Recommendations (top k): {'Pulp Fiction'}
# Precision@k: 0.02
# Recall@k: 0.041666666666666664
# ----------------------------------------
# User: 323
# Relevant Recommendations (top k): set()
# Precision@k: 0.0
# Recall@k: 0.0
# ----------------------------------------
# User: 232
# Relevant Recommendations (top k): {'Forrest Gump', 'Gladiator', 'Pulp Fiction', 'Inception', 'Fight Club'}
# Precision@k: 0.1
# Recall@k: 0.022935779816513763
# ----------------------------------------
# User: 186
# Relevant Recommendations (top k): set()
# Precision@k: 0.0
# Recall@k: 0.0
# ----------------------------------------
# User: 28
# Relevant Recommendations (top k): {'Alien', 'Gladiator', 'Pulp Fiction'}
# Precision@k: 0.06
# Recall@k: 0.026785714285714284
# ----------------------------------------
# User: 195
# Relevant Recommendations (top k): {'American History X', 'Goodfellas', 'Pulp Fiction', 'Fargo'}
# Precision@k: 0.08
# Recall@k: 0.03669724770642202
# ----------------------------------------
# User: 596
# Relevant Recommendations (top k): {'Avengers: Infinity War', 'Thor: Ragnarok', 'Guardians of the Galaxy 2', 'Inception', 'Ant-Man and the Wasp', 'Mad Max: Fury Road', 'Black Panther'}
# Precision@k: 0.14
# Recall@k: 0.04794520547945205
# ----------------------------------------
# User: 602
# Relevant Recommendations (top k): {"Schindler's List", 'Pulp Fiction'}
# Precision@k: 0.04
# Recall@k: 0.037037037037037035
# ----------------------------------------
# User: 202
# Relevant Recommendations (top k): {'Forrest Gump', 'Casablanca', 'Saving Private Ryan', 'Pulp Fiction', '12 Angry Men', 'Braveheart', 'Fight Club', 'Fargo'}
# Precision@k: 0.16
# Recall@k: 0.028070175438596492
# ----------------------------------------
# User: 200
# Relevant Recommendations (top k): {'Forrest Gump', 'Pulp Fiction', 'Fight Club'}
# Precision@k: 0.06
# Recall@k: 0.01485148514851485
# ----------------------------------------
# User: 387
# Relevant Recommendations (top k): {'Being John Malkovich', 'Requiem for a Dream', 'Mulholland Drive', 'Fight Club', 'Memento', 'Spirited Away', 'Donnie Darko', "Amores Perros (Love's a Bitch)"}
# Precision@k: 0.16
# Recall@k: 0.02564102564102564
# ----------------------------------------
# User: 510
# Relevant Recommendations (top k): set()
# Precision@k: 0.0
# Recall@k: 0.0
# ----------------------------------------
# User: 290
# Relevant Recommendations (top k): {'Goodfellas', 'Pulp Fiction'}
# Precision@k: 0.04
# Recall@k: 0.008583690987124463
# ----------------------------------------
# User: 221
# Relevant Recommendations (top k): {'12 Angry Men', 'Goodfellas', 'Pulp Fiction', 'Fight Club'}
# Precision@k: 0.08
# Recall@k: 0.01568627450980392
# ----------------------------------------
# User: 598
# Relevant Recommendations (top k): set()
# Precision@k: 0.0
# Recall@k: 0.0
# ----------------------------------------
# User: 34
# Relevant Recommendations (top k): {'Fight Club'}
# Precision@k: 0.02
# Recall@k: 0.022727272727272728
# ----------------------------------------
# User: 62
# Relevant Recommendations (top k): {'Avengers: Infinity War', 'Interstellar', 'Star Wars: Episode V - The Empire Strikes Back', 'Lord of the Rings: The Fellowship of the Ring, The', 'Spirited Away (Sen to Chihiro no kamikakushi)', 'Pulp Fiction', 'Guardians of the Galaxy', 'Inception', 'Dark Knight, The', 'Fight Club', 'Lord of the Rings: The Return of the King, The'}
# Precision@k: 0.22
# Recall@k: 0.03942652329749104
# ----------------------------------------
# User: 137
# Relevant Recommendations (top k): {'Shrek', "It's a Wonderful Life", 'Casablanca', '12 Angry Men', 'Citizen Kane', 'Finding Nemo', 'Sunset Blvd. (a.k.a. Sunset Boulevard)', 'Being John Malkovich', 'Rear Window'}
# Precision@k: 0.18
# Recall@k: 0.10112359550561797
# ----------------------------------------
# User: 606
# Relevant Recommendations (top k): {'Spirited Away', "Howl's Moving Castle", 'Princess Mononoke'}
# Precision@k: 0.06
# Recall@k: 0.004893964110929853
# ----------------------------------------
# User: 352
# Relevant Recommendations (top k): {'Forrest Gump', 'Memento', 'Saving Private Ryan', 'Pulp Fiction', 'Alien', 'Inception', 'Fight Club'}
# Precision@k: 0.14
# Recall@k: 0.03977272727272727
# ----------------------------------------
# User: 572
# Relevant Recommendations (top k): {'Forrest Gump', 'Saving Private Ryan'}
# Precision@k: 0.04
# Recall@k: 0.01652892561983471
# ----------------------------------------
# User: 129
# Relevant Recommendations (top k): {'Matrix, The'}
# Precision@k: 0.02
# Recall@k: 0.010526315789473684
# ----------------------------------------
# User: 279
# Relevant Recommendations (top k): set()
# Precision@k: 0.0
# Recall@k: 0.0
# ----------------------------------------
# User: 428
# Relevant Recommendations (top k): {'Shaun of the Dead', 'Kill Bill: Vol. 1', 'Team America: World Police', 'Harold and Kumar Go to White Castle', 'Crouching Tiger, Hidden Dragon', 'Training Day', 'Alien', 'Fight Club', 'Kill Bill: Vol. 2'}
# Precision@k: 0.18
# Recall@k: 0.21428571428571427
# ----------------------------------------
# User: 152
# Relevant Recommendations (top k): {'Fight Club'}
# Precision@k: 0.02
# Recall@k: 0.022727272727272728
# ----------------------------------------
# User: 328
# Relevant Recommendations (top k): {'Pulp Fiction', '12 Angry Men', 'Goodfellas', "Schindler's List", 'Fight Club'}
# Precision@k: 0.1
# Recall@k: 0.052083333333333336
# ----------------------------------------
# User: 427
# Relevant Recommendations (top k): {'American History X', 'Pulp Fiction', 'Memento'}
# Precision@k: 0.06
# Recall@k: 0.1111111111111111
# ----------------------------------------
# User: 367
# Relevant Recommendations (top k): {'Jurassic Park', 'Forrest Gump'}
# Precision@k: 0.04
# Recall@k: 0.015384615384615385
# ----------------------------------------
# User: 560
# Relevant Recommendations (top k): {'Kill Bill: Vol. 1', 'Drive', 'Black Swan', 'Requiem for a Dream', 'Eternal Sunshine of the Spotless Mind', 'Fight Club', 'Inglourious Basterds', 'Gone Girl', 'Inception', 'Mad Max: Fury Road', 'Catch Me If You Can', 'Lord of the Rings: The Fellowship of the Ring, The', 'Spirited Away', 'Kill Bill: Vol. 2', 'The Martian', 'Snatch'}
# Precision@k: 0.32
# Recall@k: 0.0761904761904762
# ----------------------------------------
# User: 19
# Relevant Recommendations (top k): {'Fight Club'}
# Precision@k: 0.02
# Recall@k: 0.009523809523809525
# ----------------------------------------
# User: 474
# Relevant Recommendations (top k): {'Kill Bill: Vol. 1', 'Spirited Away (Sen to Chihiro no kamikakushi)', 'Pulp Fiction', 'Fight Club', 'Kill Bill: Vol. 2'}
# Precision@k: 0.1
# Recall@k: 0.0063532401524777635
# ----------------------------------------
# User: 189
# Relevant Recommendations (top k): {'Inception'}
# Precision@k: 0.02
# Recall@k: 0.05555555555555555
# ----------------------------------------
# User: 556
# Relevant Recommendations (top k): {"Pan's Labyrinth"}
# Precision@k: 0.02
# Recall@k: 0.037037037037037035
# ----------------------------------------
# User: 3
# Relevant Recommendations (top k): {'Alien'}
# Precision@k: 0.02
# Recall@k: 0.0625
# ----------------------------------------
# User: 1
# Relevant Recommendations (top k): set()
# Precision@k: 0.0
# Recall@k: 0.0
# ----------------------------------------
# User: 217
# Relevant Recommendations (top k): {'Toy Story'}
# Precision@k: 0.02
# Recall@k: 0.01020408163265306
# ----------------------------------------
# User: 282
# Relevant Recommendations (top k): {'Inception', 'The Martian'}
# Precision@k: 0.04
# Recall@k: 0.01092896174863388
# ----------------------------------------
# User: 310
# Relevant Recommendations (top k): {'Lost in Translation'}
# Precision@k: 0.02
# Recall@k: 0.02564102564102564
# ----------------------------------------
# User: 91
# Relevant Recommendations (top k): {'Blade Runner', 'Kill Bill: Vol. 1', 'Star Wars: Episode V - The Empire Strikes Back', 'Monty Python and the Holy Grail', 'Indiana Jones and the Last Crusade', 'Spirited Away (Sen to Chihiro no kamikakushi)', 'Princess Mononoke (Mononoke-hime)', 'Office Space', 'Toy Story', 'Raiders of the Lost Ark (Indiana Jones and the Raiders of the Lost Ark)', 'Star Wars: Episode VI - Return of the Jedi', 'Star Wars: Episode IV - A New Hope', 'For a Few Dollars More (Per qualche dollaro in più)', 'Memento', 'Kill Bill: Vol. 2', 'Terminator 2: Judgment Day', 'Alien', 'Pulp Fiction', 'Fight Club', 'Aliens', 'Seven (a.k.a. Se7en)', 'Jurassic Park', 'Toy Story 2'}
# Precision@k: 0.46
# Recall@k: 0.09663865546218488
# ----------------------------------------
# User: 103
# Relevant Recommendations (top k): {'Forrest Gump', 'Interstellar', 'Good Will Hunting', 'WALL·E', 'Memento', 'Spirited Away (Sen to Chihiro no kamikakushi)', 'City of God (Cidade de Deus)', 'Saving Private Ryan', 'Pulp Fiction', 'American History X', 'Inception', 'Goodfellas', 'Toy Story', 'Fight Club', 'Fargo'}
# Precision@k: 0.3
# Recall@k: 0.06172839506172839
# ----------------------------------------
# User: 566
# Relevant Recommendations (top k): {"Schindler's List", 'Forrest Gump', 'Pulp Fiction'}
# Precision@k: 0.06
# Recall@k: 0.07142857142857142
# ----------------------------------------
# User: 298
# Relevant Recommendations (top k): {'Kill Bill: Vol. 1', 'Spirited Away (Sen to Chihiro no kamikakushi)', 'Pulp Fiction', 'Goodfellas', 'Fight Club', 'Kill Bill: Vol. 2'}
# Precision@k: 0.12
# Recall@k: 0.07058823529411765
# ----------------------------------------
# User: 381
# Relevant Recommendations (top k): {'Fight Club'}
# Precision@k: 0.02
# Recall@k: 0.004629629629629629
# ----------------------------------------
# User: 292
# Relevant Recommendations (top k): {'Forrest Gump'}
# Precision@k: 0.02
# Recall@k: 0.005319148936170213
# ----------------------------------------
# User: 43
# Relevant Recommendations (top k): set()
# Precision@k: 0.0
# Recall@k: 0.0
# ----------------------------------------
# User: 50
# Relevant Recommendations (top k): {'Spirited Away (Sen to Chihiro no kamikakushi)', 'Pulp Fiction', 'Fargo'}
# Precision@k: 0.06
# Recall@k: 0.07894736842105263
# ----------------------------------------
# User: 46
# Relevant Recommendations (top k): {'Die Hard'}
# Precision@k: 0.02
# Recall@k: 0.037037037037037035
# ----------------------------------------
# User: 564
# Relevant Recommendations (top k): set()
# Precision@k: 0.0
# Recall@k: 0.0
# ----------------------------------------
# User: 382
# Relevant Recommendations (top k): {'Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb', 'Forrest Gump', 'WALL·E', 'Casablanca', 'Memento', 'Alien', 'Pulp Fiction', 'Saving Private Ryan', 'Raiders of the Lost Ark (Indiana Jones and the Raiders of the Lost Ark)', 'Inception', "Schindler's List", 'Psycho', 'Fight Club'}
# Precision@k: 0.26
# Recall@k: 0.11926605504587157
# ----------------------------------------
# User: 48
# Relevant Recommendations (top k): set()
# Precision@k: 0.0
# Recall@k: 0.0
# ----------------------------------------
# User: 338
# Relevant Recommendations (top k): {'Pulp Fiction', 'Fight Club'}
# Precision@k: 0.04
# Recall@k: 0.13333333333333333
# ----------------------------------------
# User: 475
# Relevant Recommendations (top k): {'Star Wars: Episode V - The Empire Strikes Back', 'The Hunger Games: Catching Fire', 'Harry Potter and the Order of the Phoenix', 'Guardians of the Galaxy', 'Harry Potter and the Deathly Hallows: Part 2'}
# Precision@k: 0.1
# Recall@k: 0.0364963503649635
# ----------------------------------------
# User: 7
# Relevant Recommendations (top k): {'Die Hard', 'X-Men'}
# Precision@k: 0.04
# Recall@k: 0.02857142857142857
# ----------------------------------------
# User: 469
# Relevant Recommendations (top k): {"Schindler's List", 'Goodfellas', 'Pulp Fiction'}
# Precision@k: 0.06
# Recall@k: 0.011278195488721804
# ----------------------------------------
# User: 256
# Relevant Recommendations (top k): {'Die Hard', 'WALL·E', 'Interstellar', 'Inglourious Basterds', 'Django Unchained'}
# Precision@k: 0.1
# Recall@k: 0.03875968992248062
# ----------------------------------------
# User: 132
# Relevant Recommendations (top k): {'Forrest Gump', 'Fight Club', 'Pulp Fiction', 'Memento', 'Léon: The Professional'}
# Precision@k: 0.1
# Recall@k: 0.07246376811594203
# ----------------------------------------
# User: 480
# Relevant Recommendations (top k): set()
# Precision@k: 0.0
# Recall@k: 0.0
# ----------------------------------------
# User: 227
# Relevant Recommendations (top k): {'The Dark Knight', 'Pulp Fiction', 'Fight Club'}
# Precision@k: 0.06
# Recall@k: 0.03896103896103896
# ----------------------------------------
# User: 226
# Relevant Recommendations (top k): {'Pulp Fiction', 'Fight Club'}
# Precision@k: 0.04
# Recall@k: 0.008032128514056224
# ----------------------------------------
# User: 368
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 587
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 488
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 135
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 535
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 529
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 14
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 534
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 29
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 21
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 112
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 502
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 339
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 27
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 608
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 187
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 551
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 285
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 370
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 481
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 379
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 212
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 160
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 121
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 437
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 577
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 562
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 477
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 213
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 590
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 259
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 222
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 105
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 309
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 246
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 248
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 332
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 303
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 600
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 489
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 306
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 4
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 58
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 76
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 418
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 64
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 457
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 287
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 39
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 18
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 146
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 24
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 410
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 169
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 522
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 219
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 141
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 230
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 462
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 199
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 445
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 317
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 355
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 453
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 472
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 594
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 369
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 357
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 280
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 494
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 239
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 452
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 66
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 580
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 586
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 517
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 220
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 479
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 41
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 313
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 420
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 597
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 405
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 495
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 441
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 100
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 593
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 30
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 351
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 346
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 528
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 579
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 83
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 38
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 503
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 115
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 275
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 371
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 12
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 330
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 63
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 582
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 104
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 344
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 356
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 271
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 607
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 79
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 130
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 159
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 247
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 211
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 301
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 456
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 52
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 238
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 497
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 123
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 101
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 240
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 552
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 165
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 265
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 372
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 84
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 70
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 225
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 484
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 573
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 464
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 65
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 249
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 150
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 576
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 361
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 520
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 119
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 334
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 117
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 98
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 491
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 96
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 20
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 185
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 347
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 120
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 294
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 197
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 365
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 390
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 17
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 234
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 177
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 153
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 460
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 411
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 260
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 214
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 74
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 540
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 555
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 483
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 11
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 426
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 49
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 396
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 570
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 233
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 272
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 13
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 429
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 568
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 546
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 533
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 97
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 15
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 109
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 198
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 331
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 548
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 209
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 386
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 318
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 268
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 385
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 478
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 300
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 299
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 218
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 99
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 180
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 523
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 490
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 417
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 110
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 326
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 216
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 95
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 113
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 559
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 482
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 527
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 451
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 553
# ...
# Recall@k: 0.0
# ----------------------------------------
# User: 470
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 348
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 360
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 35
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 537
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 284
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 465
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 539
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 9
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 526
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 40
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 463
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 364
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 504
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 336
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 513
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 342
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 173
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 431
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 458
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 321
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 26
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 421
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 78
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 273
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 544
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 516
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 439
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 71
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 44
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 532
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 588
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 144
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 302
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 261
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 128
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 335
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 493
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 134
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 170
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 320
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 413
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 319
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 228
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 124
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 236
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 55
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 408
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 569
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 541
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 168
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 341
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 422
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 519
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 609
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 545
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 87
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 163
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 192
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 291
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 536
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 278
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 435
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 366
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 315
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 60
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 2
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 515
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 207
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 446
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 147
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 505
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 363
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 324
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 468
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 67
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 164
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 549
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 345
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 133
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 378
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 243
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 521
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 172
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 258
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 92
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 397
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 467
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 565
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 507
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 538
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 501
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 142
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 235
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 205
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 262
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 443
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 196
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 485
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 175
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 531
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 194
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 224
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 333
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 126
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 403
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 575
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 327
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 203
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 547
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 295
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 449
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 399
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 118
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 293
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 388
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 394
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 250
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 530
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 407
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 461
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 5
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 550
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 349
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 311
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 578
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 158
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 257
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 496
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 392
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 138
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# User: 375
# Relevant Recommendations (top k): set()
# Precision@k: 0
# Recall@k: 0.0
# ----------------------------------------
# Average Precision@50 across all users: 0.014098360655737687
# Average Recall@50 across all users: 0.0058787183028400905
